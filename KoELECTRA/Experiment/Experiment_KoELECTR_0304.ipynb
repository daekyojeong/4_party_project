# %% [markdown]
# # Pytorch + HuggingFace
# ## KoElectra Model
# 박장원님의 KoElectra-small 사용<br>
# https://monologg.kr/2020/05/02/koelectra-part1/<br>
# https://github.com/monologg/KoELECTRA
#
# ## Dataset
# 네이버 영화 리뷰 데이터셋<br>
# https://github.com/e9t/nsmc
#
# ## References
# - https://huggingface.co/transformers/training.html
# - https://tutorials.pytorch.kr/beginner/data_loading_tutorial.html
# - https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html
# - https://wikidocs.net/44249
#
# ## 주의사항
# 꼭 GPU로 해주세요 - 1epoch 당 약 20분 소요

# %%
# HuggingFace transformers 설치 및 NSMC 데이터셋 다운로드
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 6.0MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 38.0MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 36.3MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=f7baad4a69c0547cc82114eb8158781c13680fc692f91508ef4967e8acc8b020
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.3.3

# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm
import gc
from sklearn.model_selection import KFold
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('./drive/MyDrive/4_party_project')

# %%
# GPU 사용
device = torch.device("cuda")

# %% [markdown]
# # Dataset 만들어서 불러오기

# %%
#naver movie, Hotel, shopping 
class NHSDataset(Dataset): 
  
  def __init__(self, csv_file):
    # NaN값 제거...
    self.dataset = pd.read_csv(csv_file, sep='\t').dropna(axis=0) 
    # 중복제거
    self.dataset.drop_duplicates(subset=['Text'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-small-v2-discriminator")
    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)
  
  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 0:2].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=256,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    
    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y, text

# %%
#train데이터 test데이터 NHSDataset class에 넣어줌
train_dataset = NHSDataset('train.txt')
test_dataset = NHSDataset('test.txt')
# Out:
#               Label      len_text
# count  79171.000000  79171.000000
# mean       0.505286      7.710904
# std        0.499975      7.083011
# min        0.000000      2.000000
# 25%        0.000000      4.000000
# 50%        1.000000      6.000000
# 75%        1.000000      9.000000
# max        1.000000    272.000000

# %% [markdown]
# # Create Model

# %%
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-small-v2-discriminator").to(device)

# 한번 실행해보기
# text, attention_mask, y = train_dataset[0]
# model(text.unsqueeze(0).to(device), attention_mask=attention_mask.unsqueeze(0).to(device))
# Out:
# Some weights of the model checkpoint at monologg/koelectra-small-v2-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-small-v2-discriminator and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Model 저장되있는거 돌려보기

# %%
# model.load_state_dict(torch.load("원하는모델.pt"))
# text, attention_mask, y = train_dataset[0]
# model(text.unsqueeze(0).to(device), attention_mask=attention_mask.unsqueeze(0).to(device))
# Out:
# <All keys matched successfully>

# %%
# 모델 레이어 보기
model
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(32200, 128, padding_idx=0)
#       (position_embeddings): Embedding(512, 128)
#       (token_type_embeddings): Embedding(2, 128)
#       (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (embeddings_project): Linear(in_features=128, out_features=256, bias=True)
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=256, out_features=256, bias=True)
#               (key): Linear(in_features=256, out_features=256, bias=True)
#               (value): Linear(in_features=256, out_features=256, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=256, out_features=256, bias=True)
#               (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=1024, out_features=256, bias=True)
#             (LayerNorm): LayerNorm((256,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=256, out_features=256, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=256, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# # Learn

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
epochs = 3
batch_size = 64

# %%
optimizer = AdamW(model.parameters(), lr=1e-5)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %%
losses = []
accuracies = []

for i in range(epochs):
  total_loss = 0.0
  correct = 0
  total = 0
  batches = 0

  model.train()

  for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
    optimizer.zero_grad()
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    loss = F.cross_entropy(y_pred, y_batch)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()

    _, predicted = torch.max(y_pred, 1)
    correct += (predicted == y_batch).sum()
    total += len(y_batch)

    batches += 1
    if batches % 100 == 0:
      print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)
  
  losses.append(total_loss)
  accuracies.append(correct.float() / total)
  print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1238.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Batch Loss: 68.04444950819016 Accuracy: tensor(0.6166, device='cuda:0')
# Batch Loss: 121.99107959866524 Accuracy: tensor(0.7417, device='cuda:0')
# Batch Loss: 161.02170032262802 Accuracy: tensor(0.7917, device='cuda:0')
# Batch Loss: 192.06309816241264 Accuracy: tensor(0.8208, device='cuda:0')
# Batch Loss: 220.01130594313145 Accuracy: tensor(0.8386, device='cuda:0')
# Batch Loss: 246.99482993781567 Accuracy: tensor(0.8502, device='cuda:0')
# Batch Loss: 271.4609081298113 Accuracy: tensor(0.8600, device='cuda:0')
# Batch Loss: 296.4556524157524 Accuracy: tensor(0.8665, device='cuda:0')
# Batch Loss: 320.52793546020985 Accuracy: tensor(0.8719, device='cuda:0')
# Batch Loss: 343.85167184472084 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 366.7053650841117 Accuracy: tensor(0.8800, device='cuda:0')
# Batch Loss: 388.9286892451346 Accuracy: tensor(0.8837, device='cuda:0')
#
# Train Loss: 397.42890245094895 Accuracy: tensor(0.8847, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=1238.0), HTML(value='')))
# Batch Loss: 21.361451275646687 Accuracy: tensor(0.9245, device='cuda:0')
# Batch Loss: 42.3336443528533 Accuracy: tensor(0.9248, device='cuda:0')
# Batch Loss: 63.0704293474555 Accuracy: tensor(0.9249, device='cuda:0')
# Batch Loss: 83.1251098960638 Accuracy: tensor(0.9264, device='cuda:0')
# Batch Loss: 103.39676908403635 Accuracy: tensor(0.9272, device='cuda:0')
# Batch Loss: 123.6457470394671 Accuracy: tensor(0.9271, device='cuda:0')
# Batch Loss: 143.67531633749604 Accuracy: tensor(0.9274, device='cuda:0')
# Batch Loss: 164.34339333698153 Accuracy: tensor(0.9271, device='cuda:0')
# Batch Loss: 184.84964944794774 Accuracy: tensor(0.9273, device='cuda:0')
# Batch Loss: 205.8334901072085 Accuracy: tensor(0.9269, device='cuda:0')
# Batch Loss: 225.96552058681846 Accuracy: tensor(0.9271, device='cuda:0')
# Batch Loss: 245.39845236763358 Accuracy: tensor(0.9270, device='cuda:0')
#
# Train Loss: 252.95645774528384 Accuracy: tensor(0.9271, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=1238.0), HTML(value='')))
# Batch Loss: 17.844703748822212 Accuracy: tensor(0.9372, device='cuda:0')
# Batch Loss: 36.90201371908188 Accuracy: tensor(0.9362, device='cuda:0')
# Batch Loss: 55.745037730783224 Accuracy: tensor(0.9356, device='cuda:0')
# Batch Loss: 74.72837808355689 Accuracy: tensor(0.9346, device='cuda:0')
# Batch Loss: 93.69651899859309 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 112.30201808363199 Accuracy: tensor(0.9333, device='cuda:0')
# Batch Loss: 130.68957451730967 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 149.46112121641636 Accuracy: tensor(0.9335, device='cuda:0')
# Batch Loss: 167.79560147598386 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 186.35213939473033 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 204.35872882977128 Accuracy: tensor(0.9341, device='cuda:0')
# Batch Loss: 224.69901215657592 Accuracy: tensor(0.9337, device='cuda:0')
#
# Train Loss: 231.33616605773568 Accuracy: tensor(0.9338, device='cuda:0')

# %% [markdown]
# # 테스트 데이터셋 정확도및 강한(긍정,부정) 확률 확인

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch , original_text in tqdm(test_loader):
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    for idx in range(len(y_pred)):
      print(f'기존문장: {original_text[idx]}')
      pred_tensor = F.sigmoid(y_pred[idx])
      print(f'긍정확률={round(float(pred_tensor[0]*100),2)}%, 부정확률={round(float(pred_tensor[1]*100),2)}%')
      print("")
    _, predicted = torch.max(y_pred, 1)
    test_correct += (predicted == y_batch).sum()
    test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1285.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2155: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Streaming output truncated to the last 5000 lines.
# 제가 묵었던방은 욕실이 없었지만 그외는 좋았네요
# tensor([0.4711, 0.5214], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 가성비 좋아요
# tensor([0.1037, 0.8958], device='cuda:0', grad_fn=<SigmoidBackward>)
# 4성인데 4성 느낌이 아니에여ㅠ
# tensor([0.9533, 0.0414], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 문이 없다는 점, 신발장이나 신발 놔두는 부분이 애매하다는 점이 흠이라면 흠인데 저는 사실 별 상관은 없었어요
# tensor([0.7912, 0.2050], device='cuda:0', grad_fn=<SigmoidBackward>)
# 옆방이랑 방음이 안되서 새벽5시까지 떠드는소리에 잠을못잠 아..
# tensor([0.9343, 0.0585], device='cuda:0', grad_fn=<SigmoidBackward>)
# 어머니가 맛있게 드셔서 만족스러웠습니다.
# tensor([0.0806, 0.9180], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비 갑이구요
# tensor([0.0478, 0.9512], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구는 너무너무 안락하고 좋았습니다
# tensor([0.1597, 0.8356], device='cuda:0', grad_fn=<SigmoidBackward>)
# 역 근처에 주변 맛집도 많아서 넘 좋아요
# tensor([0.0455, 0.9548], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 굉장히 푹신합니다.
# tensor([0.0410, 0.9595], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방이 넓고 침구가 편안, 직원분들도 친철, 가성비 굿! 루프탑라운지가 좋았어요.
# tensor([0.0358, 0.9648], device='cuda:0', grad_fn=<SigmoidBackward>)
# 평소에 허리가 안좋은데 다리를 살짝 올려서 자니 훨씬 편안하더라구요.
# tensor([0.0299, 0.9704], device='cuda:0', grad_fn=<SigmoidBackward>)
# 또한 통유리라서 문을 열어서 환기를 시킬수 없는것이 조금 아쉬웠다.
# tensor([0.9183, 0.0728], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지하철 ktx 지나가는 영등포 역사 철로가 바로 지나가서 소리는 났는데 정겹고 좋았어요
# tensor([0.0450, 0.9551], device='cuda:0', grad_fn=<SigmoidBackward>)
# 복도에 담배냄새가 진동하는데..
# tensor([0.7479, 0.2460], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들도 친절하시고 응대도 잘해주셨습니다. 가성비가 아주 좋았습니다.
# tensor([0.0517, 0.9475], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다음에도 다시 이용할거예요.
# tensor([0.6937, 0.2962], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원분들이 엄청나게 친절하셨어요// 룸 서비스도 만족스러웠습니다///
# tensor([0.0357, 0.9643], device='cuda:0', grad_fn=<SigmoidBackward>)
# 명동역이랑 굉장히 가깝고 명동거리랑도 가깝습니다
# tensor([0.0331, 0.9675], device='cuda:0', grad_fn=<SigmoidBackward>)
# 키큰분들은 옷장갈때 tv에 머리 부딪힐수있어요
# tensor([0.9673, 0.0271], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전형적인 일본식 호텔처럼 작지만 갖출 것 다 갖춘 실속있는 호텔이었음. 호텔 내 전구역에서 사용 가능한 실내복도 좋았고 사우나도 좋았음. 가성비 좋음
# tensor([0.0336, 0.9667], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장도 너무좋앗고 객실상태도 완벽했어요.
# tensor([0.0260, 0.9742], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사우나 시설이 특히 좋아요
# tensor([0.0396, 0.9603], device='cuda:0', grad_fn=<SigmoidBackward>)
# 바로 옆에 익선동 거리가 있어 구경하기 좋네요.
# tensor([0.0229, 0.9770], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깔끔한숙소. 심플하면서 정갈한 조식. 놀기 좋은 풀과 바.
# tensor([0.0225, 0.9774], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다른건 다 너무 좋았지만 어매니티로 주신 샴푸 향이 좋지 않아서 아쉬웠습니다.
# tensor([0.9631, 0.0318], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구도 편안하고 방도 청결하고 아늑하니 좋았고 지하철역에서 가깝고 주변에 마트나 커피숍 등 인프라가 좋아서 좋네요
# tensor([0.0464, 0.9541], device='cuda:0', grad_fn=<SigmoidBackward>)
# 배관 물소리가 조금 크게 들려서 예민한 사람은 신경쓰일수도. 수건에 락스냄새가 매우 많이 남.
# tensor([0.9504, 0.0427], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오래된 호텔임에도 청결하고 직원들이 친절해서 좋았습니다.
# tensor([0.0446, 0.9554], device='cuda:0', grad_fn=<SigmoidBackward>)
# 옆방 소리가 너무 시끄러웠고 와이파이가 자꾸 끊기면서 잘 되지않아 너무 불편함
# tensor([0.9096, 0.0835], device='cuda:0', grad_fn=<SigmoidBackward>)
# 일찍 갔는데도 음식이 많이 식어있어있더라구요..
# tensor([0.9320, 0.0632], device='cuda:0', grad_fn=<SigmoidBackward>)
# 왔다갔다 하는게 번거로움.
# tensor([0.9360, 0.0581], device='cuda:0', grad_fn=<SigmoidBackward>)
# 리모델링되어서 룸이 매우 쾌적했습니다.
# tensor([0.0311, 0.9688], device='cuda:0', grad_fn=<SigmoidBackward>)
# 디너 음식 중 한 개가 데워지지 않고 있었는데, 지적했지만 시정하지 않음. 어리고 작은 단발 여직원. 29일 디너 타임 오후 9시경. 본인이 알고 있을 것.
# tensor([0.9681, 0.0265], device='cuda:0', grad_fn=<SigmoidBackward>)
# 근처에 롯데월드 백화점있어서 좋았고 매우 깨끗!했어요
# tensor([0.0626, 0.9379], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방안이 조금 건조했고 자는데 환풍기소리가 크게나서 중간에 한번 깼습니다.
# tensor([0.9574, 0.0354], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아침식사시간이 너무 늦어요
# tensor([0.9366, 0.0556], device='cuda:0', grad_fn=<SigmoidBackward>)
# 음식이 조금 더 다양했으면 좋을 것 같습니다.
# tensor([0.9303, 0.0616], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아침식사는 안했지만, 침대가 너무편안하고 리버뷰 방이라서 너무 편했습니다,
# tensor([0.0196, 0.9806], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔로 발전중
# tensor([0.0514, 0.9481], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1. 편안한 침구와 소파 2. 조용함 3. 친절한 직원들 4. 인테리어 디테일
# tensor([0.0298, 0.9709], device='cuda:0', grad_fn=<SigmoidBackward>)
# 3층 식당은 임의로 조기 마감을 함에도 미리 공지를 해주지 않아서 원활한 식사를 하지 못했다
# tensor([0.9499, 0.0435], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원분들도 친절하고 주변에 식당 커피점 있어서 편했어요
# tensor([0.0452, 0.9544], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오전에 쉬는사이 창문에 쾅쾅 소리가 들려서 쳐다봤더니 유리창을 청소해주고 계셨습니다.
# tensor([0.9288, 0.0657], device='cuda:0', grad_fn=<SigmoidBackward>)
# 고층뷰이고, 한면 전체가 창문이어서 답답하지않고 바깥을 볼 수 있어 좋았습니다.
# tensor([0.0240, 0.9762], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들이 친절했고 로비층이 모던랑 디자인으로 마음에 들었습니다.
# tensor([0.0379, 0.9619], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 조용해요.
# tensor([0.0525, 0.9468], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 좋아 이동하기 너무 편햇고 직원분들이 친절햇어요
# tensor([0.0313, 0.9688], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 세면대 이용이 불편했습니다.
# tensor([0.9271, 0.0667], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔의 주차장이 협소하니 자차를 권장하지 않는다던지, 예약이 필요하다던지 미리 알려줬으면 기대하지 않았을 건데 예약도 필요없고 무료라고 하더니 주차장이 너무 작아 10분거리에 마련한 주차장에 가서 주차하라고 하더라구요.
# tensor([0.8861, 0.1074], device='cuda:0', grad_fn=<SigmoidBackward>)
# 접근성은 최고.. 시설은 깨끗하고 조용하고 만족합니다.
# tensor([0.1471, 0.8501], device='cuda:0', grad_fn=<SigmoidBackward>)
# 별도로 저는 돈주고 식권 구매해서 그런지 더 실망했습니다.
# tensor([0.9417, 0.0518], device='cuda:0', grad_fn=<SigmoidBackward>)
# 내부 인테리어가 너무 좋았고 방 넓이도 생각보다 넓어서 쾌적했습니다
# tensor([0.0338, 0.9667], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전반적으로 만족했습니다
# tensor([0.3566, 0.6411], device='cuda:0', grad_fn=<SigmoidBackward>)
# 모텔촌 내에 위치해 있어 부담스러웠어요.
# tensor([0.9606, 0.0335], device='cuda:0', grad_fn=<SigmoidBackward>)
# 어메니티 향이 개인적으로 좋았어요.
# tensor([0.0468, 0.9522], device='cuda:0', grad_fn=<SigmoidBackward>)
# 안좋은 점이 있다면 저는 현금결제라는걸 본적이 없는것 같은데 갑자기 현금결제라고 하시더라구요.
# tensor([0.7849, 0.2069], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주차장 기본 이용 외에 예상치 못한 현장에서 현금 추가비용 청구과 발비용 청구가 당황스럽긴했습니다.
# tensor([0.9699, 0.0252], device='cuda:0', grad_fn=<SigmoidBackward>)
# 트윈배였는데 작은 침대가 너무 작아서 수면을 취하기가 쉽지 않았습니다
# tensor([0.9501, 0.0436], device='cuda:0', grad_fn=<SigmoidBackward>)
# 강남 관광호텔?느낌이었어요......
# tensor([0.9489, 0.0441], device='cuda:0', grad_fn=<SigmoidBackward>)
# 좋은 위치, 넓은 객실, well cleaned.
# tensor([0.0329, 0.9672], device='cuda:0', grad_fn=<SigmoidBackward>)
# 3일 있는동안 죽어있는 벌레들을 그대로 치우지 않고 먼지도 많은 편입니다
# tensor([0.9569, 0.0362], device='cuda:0', grad_fn=<SigmoidBackward>)
# 칫솔과 치약이 유료에요
# tensor([0.9675, 0.0268], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지하에 있는 이용시설을 이용할 수 없어 아쉬움
# tensor([0.9056, 0.0870], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그 외 음주 관련 서비스가 좋음 아이스버켓, 얼음, 잔 등등
# tensor([0.1768, 0.8236], device='cuda:0', grad_fn=<SigmoidBackward>)
# 리셉션 직원이 불친절했습니다
# tensor([0.9456, 0.0492], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대 협탁 뒤에 콘센트쓰려고 협탁 밀었는데 쓰레기가 좀... 나와서 당황ㅋㅋ 화장대 밑 콘센트도 부서질까봐ㅠ 불안 ㅠ 그리고 커피잔이 설거지가 제대로 안 된 상태여서 찝찝했네요
# tensor([0.9146, 0.0803], device='cuda:0', grad_fn=<SigmoidBackward>)
# 에어컨 온도도 적당했고, 금새 시원해졌습니다.
# tensor([0.0308, 0.9691], device='cuda:0', grad_fn=<SigmoidBackward>)
# 솔직히 가격 대비 방 크기가 작은 거 같아서 별로였습니다.
# tensor([0.6354, 0.3615], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청소문제가 가장 실망했습니다.
# tensor([0.9657, 0.0289], device='cuda:0', grad_fn=<SigmoidBackward>)
# 생각보다 방이작았음
# tensor([0.9170, 0.0753], device='cuda:0', grad_fn=<SigmoidBackward>)
# 어매니티도 잘 구비되어 있고 시설은 낡았지만 깨끗해요
# tensor([0.0267, 0.9736], device='cuda:0', grad_fn=<SigmoidBackward>)
# 체크인시에 재고 부족이나 안내도 없었고 새벽시간 카운터는 정말.. 불친절의 끝 호텔이 아니라 모텔 온줄 알았네요
# tensor([0.9558, 0.0380], device='cuda:0', grad_fn=<SigmoidBackward>)
# 임시공휴일낀 주말 체크인이라 사람이 엄청 붐볐음. 사전대처가 좀 안됐었던것 같음. 마스크쓰고 로비에서 3-40분 기다리는데 너무 힘들었음.
# tensor([0.9587, 0.0357], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그 외엔 다 좋았어요!
# tensor([0.7824, 0.2048], device='cuda:0', grad_fn=<SigmoidBackward>)
# 코로나로 조식미제공
# tensor([0.0477, 0.9517], device='cuda:0', grad_fn=<SigmoidBackward>)
# 일단 위치가 경의선이나 2호선 둘다 가까워서 좋아요
# tensor([0.0300, 0.9705], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 침대와 베개가 편안함. 직원들 매우 친절함.
# tensor([0.0464, 0.9529], device='cuda:0', grad_fn=<SigmoidBackward>)
# 체크인할때부터 중간중간 직원분들과 소통할 때 너무나 친절하셔서 투숙하는 내내 기분 좋은 시간을 보낼 수 있었습니다.
# tensor([0.0273, 0.9730], device='cuda:0', grad_fn=<SigmoidBackward>)
# 논현역 근처라서 좋았습니다
# tensor([0.0277, 0.9718], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗해서 좋았는데 주변에 역외에 아직은 볼게 없어서..
# tensor([0.9278, 0.0653], device='cuda:0', grad_fn=<SigmoidBackward>)
# 얼마나 떠다니는게 많은지....
# tensor([0.9339, 0.0595], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결도에 좀더 신경써 주었으면 좋겠네요
# tensor([0.9647, 0.0299], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 가짓수는 얼마없지만 아침에 먹기에 부담없이 맛있는 메뉴들로 구성되어 있었습니다.
# tensor([0.0287, 0.9705], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치..가성비..는 좋습니다.
# tensor([0.1168, 0.8808], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지하 및 지상 주차장이 있지만 호텔까지 이동하는데 거리가 좀 있습니다
# tensor([0.9621, 0.0319], device='cuda:0', grad_fn=<SigmoidBackward>)
# 딱 가격만큼 한다는 느낌. 샤워실 하수구가 잘 내려가지 않아서 샤워 정도 하면 점점 바닥에 물이 고였습니다.
# tensor([0.9568, 0.0374], device='cuda:0', grad_fn=<SigmoidBackward>)
# 또한 해피아워라운지 관련된 변경사항도 제대로 안내되지않았습미다
# tensor([0.9596, 0.0339], device='cuda:0', grad_fn=<SigmoidBackward>)
# 몇 층에서 오는지 볼 수도 없고 그게 좀 답답했어요.
# tensor([0.8749, 0.1189], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실 디자인이 뛰어났고 객실 업그레이드 되었던 점이 좋았습니다
# tensor([0.0242, 0.9760], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이호텔의 경영방침은 손님을 호구로 생각하는 나쁜 행보를 버려야 할것이다.
# tensor([0.9630, 0.0310], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음이 조금 아쉽네요
# tensor([0.9606, 0.0326], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들 서비스 교육, 화장실 변기 청소, 방음문제
# tensor([0.9622, 0.0320], device='cuda:0', grad_fn=<SigmoidBackward>)
# 창문이 없어 환기가 안되요 좁아요
# tensor([0.9516, 0.0420], device='cuda:0', grad_fn=<SigmoidBackward>)
# 프런트에 사람이 없어서 들어가는 것을 어떻게 해야하는지에 대한 안내가 필요한 것 같습니다.
# tensor([0.9488, 0.0446], device='cuda:0', grad_fn=<SigmoidBackward>)
# 레이트 체크아웃을 해줘서 좋았어요.
# tensor([0.0380, 0.9615], device='cuda:0', grad_fn=<SigmoidBackward>)
# 발렛 주차 비용이 있긴 하지만 주차도 편했습니다~
# tensor([0.0219, 0.9779], device='cuda:0', grad_fn=<SigmoidBackward>)
# 쳐다도 안보고 메뉴 고르라하고 무뚝뚝..모든게 완벽했는ㄷㅔ 마지막에 기분 상해서 나왔어요 ㅋ ㅋ
# tensor([0.9623, 0.0311], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가족을 위한 객실이 따로 없어서 3명이서 객실 두개 잡았습니다. 라운지에서 제공하는 다과들의 종류가 조금 부실하고, 라운지 내 회의실 자리까지 내주시는거는 안하느니만 못한거같습니다...
# tensor([0.8971, 0.0956], device='cuda:0', grad_fn=<SigmoidBackward>)
# 건물 옆 골목으로 들어가면 식당, 카페들도 있어서 편하게 이용했습니다!
# tensor([0.0305, 0.9698], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치는 가깝고 좋았어요~! 찾기도 쉽고 설명도 보기쉽게 되어있어서 좋았습니다~ 다만 가격에 비해 조금 아쉬운 부분도 있었어요~! ㅎㅎ 다음에 이용 할 생각 있습니다~!! ^^
# tensor([0.0418, 0.9584], device='cuda:0', grad_fn=<SigmoidBackward>)
# 올때까지 정리 부탁드린다 해도 되어있지 않아 3번 부탁한 날도 있었네요
# tensor([0.9627, 0.0328], device='cuda:0', grad_fn=<SigmoidBackward>)
# 평일이어서 수영장이 한산해서 좋았습니다
# tensor([0.0320, 0.9679], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실주방등이 너무더러워서힘듦 특히화장실은 전혀물청소가안되어있음 주방은 관리안할꺼면 없애든지 식기에 자국들이ㅈ듬뿍묻어있음
# tensor([0.9625, 0.0319], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주변에 청계천도 가깝고 가려고 계획했던 곳과도 가까웠어요!
# tensor([0.0643, 0.9350], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주변 갈매기 맛집 추천합니다 ㅎㅎㅎ
# tensor([0.1944, 0.7971], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비 좋아요
# tensor([0.2603, 0.7350], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치도 좋고 깔끔했다
# tensor([0.0518, 0.9492], device='cuda:0', grad_fn=<SigmoidBackward>)
# 특별히 없었던것같습니다.
# tensor([0.9544, 0.0386], device='cuda:0', grad_fn=<SigmoidBackward>)
# 시설도 좋고 위치도 좋았어요
# tensor([0.0716, 0.9280], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방바닥이 카펫이라 먼지가많고 건조함 방이 좁음 냉장고도 완전 작아서 맥주4캔넣으면 꽉참 새벽에 옆방 화장실소리 다들리고 .. 다른소리도 잘들림.. 방음이 잘안됨
# tensor([0.9424, 0.0497], device='cuda:0', grad_fn=<SigmoidBackward>)
# 갓성비 그자체. 접근성이 좋고 직원분들도 친절하셨어요.
# tensor([0.0270, 0.9732], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가끔 담배냄새 같은 게 나서 불쾌했구요.
# tensor([0.8796, 0.1141], device='cuda:0', grad_fn=<SigmoidBackward>)
# 집기류나 주방용품등이 조금 오래되었어요
# tensor([0.9472, 0.0456], device='cuda:0', grad_fn=<SigmoidBackward>)
# 잠자리는 편합니다
# tensor([0.0434, 0.9557], device='cuda:0', grad_fn=<SigmoidBackward>)
# 제가 머물럿던 방은 평화시장뷰라..
# tensor([0.9641, 0.0313], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이미 2박을 하고, 너무 좋아서 추가로 1박을 더 했어요.
# tensor([0.0381, 0.9613], device='cuda:0', grad_fn=<SigmoidBackward>)
# 명동 접근성이 좋다
# tensor([0.0462, 0.9538], device='cuda:0', grad_fn=<SigmoidBackward>)
# 또 밤에 누워있으면 다른 방 소리가 매우 잘들려요
# tensor([0.9266, 0.0646], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 머리카락. 에어컨소음. 발렛대기없음. 샤워기고장.
# tensor([0.9641, 0.0300], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실이 좁았지만, 괜찮았습니다.
# tensor([0.6134, 0.3899], device='cuda:0', grad_fn=<SigmoidBackward>)
# 입지 외엔 장점이 없는 오래된 호텔에 많은 걸 바란 것도 아니고 적어도 기본적인 청결과 기본적인 응대 매뉴얼을 기대했습니다.
# tensor([0.9526, 0.0408], device='cuda:0', grad_fn=<SigmoidBackward>)
# 구로디지털단지에 한국업체들과의 비지니스가 아니면 다른곳으로 옮기고싶읍니다.
# tensor([0.8877, 0.1022], device='cuda:0', grad_fn=<SigmoidBackward>)
# 생긴지 얼마되지 않은 곳이라 깔끔하고 좋았습니다.
# tensor([0.0458, 0.9534], device='cuda:0', grad_fn=<SigmoidBackward>)
# 일단 1층에 카페가 무척 맘에 들었습니다
# tensor([0.0292, 0.9711], device='cuda:0', grad_fn=<SigmoidBackward>)
# 모든게 완벽했습니다.
# tensor([0.3965, 0.5993], device='cuda:0', grad_fn=<SigmoidBackward>)
# 욕조있는방이었는데 물 빠지면서 하수구냄새가 꽤 올라왔음. 일반적인 배수구 모양이 아니라 관리가 어려울것 같았음. 하지만 이점 빼고 욕실 침실 컨디션은 좋았습니다.
# tensor([0.9345, 0.0611], device='cuda:0', grad_fn=<SigmoidBackward>)
# 커피포트 내부도 세척이 필요한 듯 해요...
# tensor([0.9571, 0.0371], device='cuda:0', grad_fn=<SigmoidBackward>)
# 체크인이 3시였는데 5시까지도 룸 준비가 안되서 웨이팅했는데 아무런 조치가 없었어요.
# tensor([0.9557, 0.0382], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대 안푹신하다는 말 있는데 침대 자체가 좀 단단한 침대더라구요.
# tensor([0.9395, 0.0530], device='cuda:0', grad_fn=<SigmoidBackward>)
# 피트니스클럽 시설이 조금 아쉬워요
# tensor([0.9617, 0.0321], device='cuda:0', grad_fn=<SigmoidBackward>)
# 찾기쉬운 위치, 룸컨디션이 만족스러웠습니다
# tensor([0.0254, 0.9750], device='cuda:0', grad_fn=<SigmoidBackward>)
# 급하게 예약해서 그런지 방이 조금 더러웟음 ㅠㅠ 머리카락과 먼지 ㅜㅜ
# tensor([0.9543, 0.0396], device='cuda:0', grad_fn=<SigmoidBackward>)
# 서울 정중앙에서 가깝게 즐길 수 있는 호캉스라니!
# tensor([0.0607, 0.9395], device='cuda:0', grad_fn=<SigmoidBackward>)
# 쾌적함 청결함 친절함
# tensor([0.0569, 0.9419], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔 위치나 객실 청결도. 신규 호텔이라 그런가 깔끔하고 층마다 정수기가 있어서 편리하다.
# tensor([0.1310, 0.8686], device='cuda:0', grad_fn=<SigmoidBackward>)
# 너무많아 글로 다 못함
# tensor([0.9538, 0.0392], device='cuda:0', grad_fn=<SigmoidBackward>)
# 기계식 주차가 되긴 하지만 매번 출입차 하기 번거롭습니다.
# tensor([0.9626, 0.0320], device='cuda:0', grad_fn=<SigmoidBackward>)
# 무사히 하루보낸점?
# tensor([0.0260, 0.9729], device='cuda:0', grad_fn=<SigmoidBackward>)
# 옆건물과 너무 붙어있어서..
# tensor([0.9426, 0.0517], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오래된 곳이라..
# tensor([0.8928, 0.0999], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 탈의실은 완전 작고 사람이 없어 이용하는데 불편은 없었지만 샤워시설이 개인 욕실수준이라는걸~~~ 나름 작은 휘트니스라고까진 아니지만 런닝머신 3대 있습니다
# tensor([0.0241, 0.9767], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대카 크고 침구깔끔해서 더 좋았구요
# tensor([0.0286, 0.9712], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대 불편
# tensor([0.9648, 0.0306], device='cuda:0', grad_fn=<SigmoidBackward>)
# 타 객실의 소음이 조금 들렸습니다.
# tensor([0.9623, 0.0327], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비가 훌륭해요
# tensor([0.0869, 0.9107], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔 자체에 정수기가 없다는게 충격..
# tensor([0.7423, 0.2492], device='cuda:0', grad_fn=<SigmoidBackward>)
# Do not disturb 버튼 해놓으면 재실 정리를 해주지 않으시는데 혹시나 실수로 눌렀을까마 문자로 한 번 더 확인차 연락 주는 것도 좋았습니다.
# tensor([0.0905, 0.9067], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그런데 앞에 띡...하니 뷰를 가리는 건물이 있었죠..
# tensor([0.9007, 0.0938], device='cuda:0', grad_fn=<SigmoidBackward>)
# 긴 시간은 아니지만 느낌이 외부자 느낌이 들어 좀 멋적었어요.
# tensor([0.9553, 0.0393], device='cuda:0', grad_fn=<SigmoidBackward>)
# 여러명이갓는데 생각보다 많이 넓어서 좋앗어요
# tensor([0.0447, 0.9552], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 침구류 위에도 머리카락이 있어서 무척이나 불쾌했어요.
# tensor([0.9444, 0.0481], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장이 작습니다
# tensor([0.9532, 0.0391], device='cuda:0', grad_fn=<SigmoidBackward>)
# 좀 추웠는데 난방 조절이 원래 안되는건지 작동이 작동이 안됐습니다.
# tensor([0.9375, 0.0556], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔 내 편의점이 없어서 바로 옆 건물로 안내 받았는데 영업을 안하더라구요ㅠㅠ 택시기사님들 시위일이어서 주변이 좀 시끄러웠습니다
# tensor([0.9497, 0.0437], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치나 가격 다 만족
# tensor([0.0467, 0.9525], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아침식사는 가성비로 보면 그저그렇습니다.
# tensor([0.2251, 0.7641], device='cuda:0', grad_fn=<SigmoidBackward>)
# 익선동 바로 옆! 데이트하기에 좋았습니다.
# tensor([0.0261, 0.9738], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결,위치 좋음
# tensor([0.0373, 0.9630], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아쉬운 점은 욕조 위에 올려져 있던 샴푸, 바디워시 등의 샘플에 머리카락 뭉텅이가 있었습니다.
# tensor([0.9495, 0.0449], device='cuda:0', grad_fn=<SigmoidBackward>)
# 또 조식에 빠짐없이 나오는 따뜻한 국과 장기 여행중에 세탁과 휘트니스 이용 시설이 있어 유용했습니다.
# tensor([0.0266, 0.9741], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가장 좋았던 점은 직원들의 친절함입니다.
# tensor([0.0446, 0.9540], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방은좀 좁았지만.
# tensor([0.8749, 0.1125], device='cuda:0', grad_fn=<SigmoidBackward>)
# 컴포트 레저 룸 왓챠랑 넷플릭스 실컷 보고 나왔어요
# tensor([0.8880, 0.1062], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비 좋음. 위치 최고. 주변에 음식점, 커피샵, 지하철역, 버스 정류장 모두 가까워요.
# tensor([0.0492, 0.9507], device='cuda:0', grad_fn=<SigmoidBackward>)
# 정말 깔끔합니다
# tensor([0.0423, 0.9564], device='cuda:0', grad_fn=<SigmoidBackward>)
# 탕안에서 목욕을 해야 물이 안넘침..
# tensor([0.9611, 0.0332], device='cuda:0', grad_fn=<SigmoidBackward>)
# 추천하고 싶은 호텔입니다.
# tensor([0.2062, 0.7925], device='cuda:0', grad_fn=<SigmoidBackward>)
# 짧게 머물러서 잘 모름
# tensor([0.0340, 0.9645], device='cuda:0', grad_fn=<SigmoidBackward>)
# 모든것이 만족스러웠어요~. 위치는 명동역 바로 코앞이고, 나름 커피제공되는 라운지도 있고, 스탭들은 아주 친절했으며, 객실 컨디션은 아주 훌륭했어요.
# tensor([0.0313, 0.9691], device='cuda:0', grad_fn=<SigmoidBackward>)
# 예전엔 욕조를 쓰고 나옴 바닥에 발닦을 수건이 준비되어 있었는데 이젠 없네요
# tensor([0.8927, 0.1002], device='cuda:0', grad_fn=<SigmoidBackward>)
# 넓은 객실, 주방, 욕실 등 시설이 깔끔하니 좋습니다. 가성비 굳
# tensor([0.0497, 0.9502], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전원코드 꼽는곳이 침상가까이없어서 아쉬움. 바닥이 마루인줄알았는데 장판임. 주차공간협소.외부에서 걸어서 들어가야함
# tensor([0.9221, 0.0709], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식이 가격에비해서 너무조촐하게 나온거같습니다
# tensor([0.9380, 0.0561], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장.스케이트장이 작아서 아쉬움 ㅠ 그래도 사람들이 매너가있어 좋았음. 스케이트장에 간식사먹는곳에 직원들이 매너가 너무 별로였음. 햄버거랑 토스트 먹는데 같이달라했는데 따로주고 햄버거 밖에두고 오래있다가 주고. 자리도 외국인자리 맡아뒀는데 우리보고 앉았다고 단발머리 아줌마 검정후리스입은직원분이 떨떠름하게했어서 기분이 매우 안좋았음. 심지어 외국인들은 스케이트타면서 자리에 잘 오지도않았음. 음식도 안시켰던것으로 기억함.한국에서 외국인차별당한 아주 더러운기분. 거기직원분들 어린분들과 남자분들 빼고는 매너가 최악이었음. 표정도 안좋고 일하기싫어보여서 부탁하는데 미안하게만듦. 아주 불편했음. 나머지 데스크와 콜직원 룸서비스직원등은 매너가 너무 좋았어요.
# tensor([0.9351, 0.0602], device='cuda:0', grad_fn=<SigmoidBackward>)
# 기다리는 시간이 좀 걸렸던 것 정도였네요.
# tensor([0.9486, 0.0450], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그래서 public으로했습니다.
# tensor([0.7559, 0.2391], device='cuda:0', grad_fn=<SigmoidBackward>)
# 티포트와 차가 준비되어 있지만 얼그레이와 제주녹차는 있는데 커피종류.. 믹스 조차 없어 아쉬움!
# tensor([0.9525, 0.0414], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방size가 작아 아쉬움.
# tensor([0.9384, 0.0558], device='cuda:0', grad_fn=<SigmoidBackward>)
# 너무 깔끔하고 좋았습니다
# tensor([0.0813, 0.9169], device='cuda:0', grad_fn=<SigmoidBackward>)
# 코엑스와 가까워서 좋았습니다.
# tensor([0.0940, 0.9057], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 사용시 투숙객이 페이를 해야하는게 좀 이해 안됨.
# tensor([0.9529, 0.0406], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치 보다는 밤에는 주변상가가 없고 다 불꺼져서 좀 무서워요;
# tensor([0.9720, 0.0233], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방도 깔끔하고 스타일러가 있어서 편리하게 잘 사용하였습니다.
# tensor([0.0367, 0.9634], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구도 완전 포근하고 푹신하진 않았지만 좋았습니다
# tensor([0.0876, 0.9105], device='cuda:0', grad_fn=<SigmoidBackward>)
# 12시 체크아웃이긴 했지만 8시경부터 옆방 청소소리가 들려서 늦잠은 안됩니다
# tensor([0.9570, 0.0371], device='cuda:0', grad_fn=<SigmoidBackward>)
# 최근에 지어진 호텔이라 그런지 객실 컨디션도 최고였어요!
# tensor([0.0270, 0.9737], device='cuda:0', grad_fn=<SigmoidBackward>)
# 욕조가 있어 굿.
# tensor([0.0286, 0.9713], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 마포와 공덕역 중간이라 이동에 편리.
# tensor([0.0225, 0.9780], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지하철 역에서 가까워 위치가 아주 만족스러웠습니다. 가격대비 시설이 좋았고 객실은 아주 깔끔했습니다.
# tensor([0.0361, 0.9637], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결. 위치. 룸 커디션
# tensor([0.0413, 0.9588], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들도 친절하셨고 방도 깨끗하고 침대도 푹신해서 숙소에 돌아와서 샤워하고 누우면 스르륵 깊은 잠을 잘 수 있었다.
# tensor([0.0299, 0.9696], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아침에 사우나 이용할 수 있어서 피로를 풀기에 좋았습니다.
# tensor([0.0290, 0.9713], device='cuda:0', grad_fn=<SigmoidBackward>)
# 매우 깨끗했습니다.
# tensor([0.0986, 0.8993], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그래도 곧바로 시정조치 해주셨고요.
# tensor([0.9497, 0.0455], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지하철에서 가깝고 청결 시원
# tensor([0.0401, 0.9597], device='cuda:0', grad_fn=<SigmoidBackward>)
# 식사도중에 직원이 실수로 그릇을 떨어뜨리기도하고 전반적으로 서비스가 아쉬워요 ㅠㅠ
# tensor([0.9253, 0.0680], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사우나 탕 물이 너무 뜨거워요ㅠㅠ
# tensor([0.9472, 0.0472], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그냥 다만 평범했다?
# tensor([0.6352, 0.3656], device='cuda:0', grad_fn=<SigmoidBackward>)
# 롯데몰과 가깝고 주변에 먹을 곳이 많아서 좋았지만 먹자골목에 붐비는 시간에 혼자 캐리어를 끌고 다니기 좀 그랬다.
# tensor([0.0435, 0.9557], device='cuda:0', grad_fn=<SigmoidBackward>)
# 몇번이고 죄송하며 당연히 객실 변경이 이루어져야한다고 설명해주신 직원분 너무 감사합니다.
# tensor([0.0382, 0.9612], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전반적으로 세련된 시설
# tensor([0.0580, 0.9392], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그래서 첫날 우리가 이용하지 못한 1인 서비스에 대한 환불이 가능하냐고 물었더니 결제는 호텔 예약 사이트에서 이미 했으므로 환불은 불가능하고 조식 이나 스파 등의 서비스로 대체 해주겠다고 하였지만 이미 우리는 조식 시간도 지난 상태였고 스파를 할 시간이 없어서 차액은 돌려 받지 못하고 체크 아웃을 했었어야 했다.
# tensor([0.9470, 0.0469], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 직원들도 친절하셨어요
# tensor([0.0375, 0.9623], device='cuda:0', grad_fn=<SigmoidBackward>)
# 심야영화나 먹을거 사오고 쇼핑하기 정말 좋습니다.
# tensor([0.0285, 0.9715], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비가 정말 최고입니다.
# tensor([0.0452, 0.9548], device='cuda:0', grad_fn=<SigmoidBackward>)
# 잘 사용하겠습니다.
# tensor([0.2847, 0.7115], device='cuda:0', grad_fn=<SigmoidBackward>)
# 처음 방문하는 호텔이라 기본적인 기대심이 이상으로 발동되어 객실로 갔는데 객실문이 이미 활짝 열려있었고 내부도 청소를 하다말아버린 것처럼 지저분 했음 이에 대하여 프론트에 연락을 하여 객실 정리가 잘안되어 있으니 객실을 바꿔달라는 요청을 드렸고 열쇠를 가지고 올라가서 방을 안내해주겠다 말한뒤 약 20분 뒤에 올라와서 갑자기 손님이 몰리는 바람에 늦게올라왔다고 했음 이 후 객실에 짐을 정리하고 업무를 보러 호텔 밖을 나왔는데 호텔에서 전화가 와서 객실 요금 정산이 부족하게 되었다며 이유인 즉슨 동명이인이 있어서 그랬다며 다시 부족한 요금을 정산해달라하는데 체크인할때를 생각해보니 전화번호를 확인 할때 내 번호가 아닌 번호를 직원분이 맞냐 물어보시길래 전혀 아니라고 하니 내 번호만 다시 물어봐서 투숙객 정보를 수정 후 객실요금을 정산했던것이 생각이 났다
# tensor([0.9379, 0.0561], device='cuda:0', grad_fn=<SigmoidBackward>)
# 차소리도 크게 들리구요.
# tensor([0.9641, 0.0298], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 좋고 항상 편안한 느낌이라 자주 이용합니다.
# tensor([0.0926, 0.9059], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실 크기 크구요
# tensor([0.0230, 0.9768], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주니어 스위트룸이 참 넓고 쾌적해서 좋았습니다
# tensor([0.0576, 0.9423], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깔끔하긴 했습니다. 시간이 좀 지나면 괜찮아질 것 같네요.
# tensor([0.3346, 0.6594], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔 잘 쉬다가 이런부분에서 좋지 않은 기억이 생기잖아요.
# tensor([0.7797, 0.2050], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 시설도 좋았습니다.
# tensor([0.0355, 0.9645], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 어메니티가 질이 떨어져 머리칼이 푸석했어요.
# tensor([0.9259, 0.0655], device='cuda:0', grad_fn=<SigmoidBackward>)
# 인사동 중심에 위치헤서, 창덕궁, 북촌마을, 익선동 등 걸어서 다닐 수 있는 곳이 가깝습니다.
# tensor([0.0328, 0.9672], device='cuda:0', grad_fn=<SigmoidBackward>)
# 도심이라 어디든 접근성이 좋아요.
# tensor([0.0765, 0.9206], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치 좋았고 객실도 깔끔했습니다.
# tensor([0.0523, 0.9484], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주로 외국인과 만나는 로비인데 청소머신의 기계음이 너무 시끄러워서 대화하기가 힘들고, 걸레질에 부딪치지않을까 신경쓰였습니다.
# tensor([0.9672, 0.0266], device='cuda:0', grad_fn=<SigmoidBackward>)
# 코로나로 부대시설을 이용하지 못하는 점이 아쉬웠습니다.
# tensor([0.9535, 0.0405], device='cuda:0', grad_fn=<SigmoidBackward>)
# 할인가 대비 정말 깔끔한 숙소.
# tensor([0.0428, 0.9561], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위차가 좋았고 직원들이 친절했습니다.
# tensor([0.0247, 0.9752], device='cuda:0', grad_fn=<SigmoidBackward>)
# 제가 만났던 직원분들 모두 다 친절하셔서 기분 좋게 머물다왔어요
# tensor([0.0859, 0.9124], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가격대비 최고입니다
# tensor([0.0705, 0.9259], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸컨디션이 상당이 좋습니다.
# tensor([0.0276, 0.9714], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 좋아서 일정이 편햤어요~
# tensor([0.0469, 0.9545], device='cuda:0', grad_fn=<SigmoidBackward>)
# 창문이 큰 편이라 밤에 추웠음. 온풍기가 벽에 달렸는데 직방으로 날아와 건조한 편
# tensor([0.9453, 0.0475], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사회적 거리두기 2단계로 인하여..클럽 라운지 이용을 못하면 객실에 음료 배치라도 했으면 하는 아쉬움..지난번에 들이지 않았던 소음이..복도에서 유난히 들림..
# tensor([0.9614, 0.0319], device='cuda:0', grad_fn=<SigmoidBackward>)
# 욕실이 좁음
# tensor([0.9588, 0.0345], device='cuda:0', grad_fn=<SigmoidBackward>)
# 일단 예약했으니 그냥 먹기는 했는데 이해가 가지 않는 부분들이 있었고 또 이런 상황에서 고객은 그냥 일방적으로 바뀐 호텔 정책에 수긍하고 아무런 배려를 받을 수 없는건지 궁금합니다. 만약에 조식이 간소화 될거라고 미리 체크인 시 말씀해주셨다면 조식 불포함으로 변경했겠죠..
# tensor([0.9275, 0.0673], device='cuda:0', grad_fn=<SigmoidBackward>)
# 홍대 합정가기 적합
# tensor([0.4649, 0.5422], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구류도 마찬가지.
# tensor([0.8958, 0.0924], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다른 직원분들은 다 친절하셨는데 체크인할때 직원분이 조금.. 제 신용카드 가져가서도 deposit으로 10만원이 추가되는지 설명도 제대로 안해주셔서 다시 여쭤봐야했어요.
# tensor([0.9625, 0.0320], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치의 장점은 말할 것도 없죠!
# tensor([0.0255, 0.9746], device='cuda:0', grad_fn=<SigmoidBackward>)
# 서비스 응대도 짱
# tensor([0.0416, 0.9576], device='cuda:0', grad_fn=<SigmoidBackward>)
# 데스크에서의 고객응대가 좋다고 말할 순 없다.
# tensor([0.5169, 0.4768], device='cuda:0', grad_fn=<SigmoidBackward>)
# 뷰 업그레이드, 바쓰티와 바쓰솔트, 조식 모두 좋았어요
# tensor([0.0248, 0.9756], device='cuda:0', grad_fn=<SigmoidBackward>)
# 작은 화장대같은 거랑 진짜 작은 침대 옆 협탁이 전부라...
# tensor([0.9566, 0.0376], device='cuda:0', grad_fn=<SigmoidBackward>)
# 참 방쪽으로 바닥에도 카페트가 젖은 느낌이었어요
# tensor([0.9106, 0.0805], device='cuda:0', grad_fn=<SigmoidBackward>)
# 난방을 켰지만 에어컨 소리가 커서 수면모드로 해놓았습니다.
# tensor([0.9198, 0.0736], device='cuda:0', grad_fn=<SigmoidBackward>)
# 올만에 서울 나들이엇는데 직원분들 넘친절하시구.. 메이드분들께서 생수도 중간중간 더 챙겨주셧어요 ..
# tensor([0.0345, 0.9648], device='cuda:0', grad_fn=<SigmoidBackward>)
# 자주 가게 되는 출장지에 있어서 기왕이면 다른 곳보다 항상 신라스테이 구로에 묶으려고 합니다.
# tensor([0.0577, 0.9428], device='cuda:0', grad_fn=<SigmoidBackward>)
# 2층 부페직원들이 좀 성의없었음
# tensor([0.9481, 0.0454], device='cuda:0', grad_fn=<SigmoidBackward>)
# 고층으로 배정해주셔서 뷰도 좋고 (날씨는 안좋았지만) 서비스도 좋았어요.
# tensor([0.0304, 0.9700], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실앞에서 화장했네요... ㅋㅋ
# tensor([0.9681, 0.0265], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음이 안되서 주변 소리 다 들립니다.
# tensor([0.9342, 0.0594], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전철역과 가깝고 주위에 편의점도 많아서 좋았습니다.
# tensor([0.0374, 0.9627], device='cuda:0', grad_fn=<SigmoidBackward>)
# 덕분에 휴가 동안 서울의 핫플레이드 이곳저곳 다녔습니다! 시설도 쾌적하고 만족합니다.
# tensor([0.0685, 0.9317], device='cuda:0', grad_fn=<SigmoidBackward>)
# 동생이랑 둘이 쓰기에는 좋았어요.
# tensor([0.0500, 0.9498], device='cuda:0', grad_fn=<SigmoidBackward>)
# 안전상 안좋지 않나 싶습니다
# tensor([0.9519, 0.0405], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 너무 푹신하며 높습니다
# tensor([0.8774, 0.1158], device='cuda:0', grad_fn=<SigmoidBackward>)
# 변기 청소가 살짝 미흡했습니다 ㅠㅠ
# tensor([0.9069, 0.0880], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원분들의 친절함이 정말 좋았습니다.
# tensor([0.0630, 0.9352], device='cuda:0', grad_fn=<SigmoidBackward>)
# 비슷한 가격의 다른 호텔에 비해 객실이 넓었어요.
# tensor([0.0264, 0.9736], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사람이 붐비지 않았던점, 객실이 청결한점
# tensor([0.0260, 0.9736], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸 서비스가 아예 안 되는 건가요?
# tensor([0.9584, 0.0346], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방넓고, 침대편안하고..수영장도 ..
# tensor([0.0258, 0.9748], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청소가 덜 되어 있더라구요....
# tensor([0.9669, 0.0275], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결상태가 좋았고 1층 로비 직원중 이름은 기억 안나는데 선더랜드대를 나온 여직원이 아주 친절했습니다.
# tensor([0.0265, 0.9733], device='cuda:0', grad_fn=<SigmoidBackward>)
# 밤에 돌아다니기엔 좀 무섭기도 했어요
# tensor([0.7857, 0.2026], device='cuda:0', grad_fn=<SigmoidBackward>)
# 인테리어가 올드함. 주변 기기음이 난다.
# tensor([0.9644, 0.0297], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실 분위기나 방 크기도 좋았습니다.
# tensor([0.0320, 0.9683], device='cuda:0', grad_fn=<SigmoidBackward>)
# 잠자리 매우 편안했어요
# tensor([0.0450, 0.9552], device='cuda:0', grad_fn=<SigmoidBackward>)
# 차량이 진입안되서 셔틀을 이용해야해서 아쉬웠어요.
# tensor([0.8875, 0.1037], device='cuda:0', grad_fn=<SigmoidBackward>)
# 매트리스가 너무 좋았는듯
# tensor([0.0414, 0.9584], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔내 편의점이나 자판기라도 있으면 좋을것 같습니다.
# tensor([0.9621, 0.0320], device='cuda:0', grad_fn=<SigmoidBackward>)
# 우리 집에서 멀다는 것 빼곤.....ㅎㅎ
# tensor([0.4067, 0.5880], device='cuda:0', grad_fn=<SigmoidBackward>)
# 로비 커피도 맛있어요,
# tensor([0.0563, 0.9430], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원분들도 아주 친절했어요.
# tensor([0.0467, 0.9523], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식도 맛있고, 무엇보다 취사시설이 있어 좋았습니다.
# tensor([0.0340, 0.9664], device='cuda:0', grad_fn=<SigmoidBackward>)
# 미리 알고 있다면 괜찮은 정도입니다.
# tensor([0.9645, 0.0291], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 변기 물 수압이 너무 약하고 청소가 부족해요
# tensor([0.9401, 0.0536], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치는 굿
# tensor([0.0847, 0.9139], device='cuda:0', grad_fn=<SigmoidBackward>)
# 푹신한 침대
# tensor([0.0552, 0.9440], device='cuda:0', grad_fn=<SigmoidBackward>)
# 홍대라는 위치는 정말 최고. 잠깐 나가면 별천지.
# tensor([0.0250, 0.9753], device='cuda:0', grad_fn=<SigmoidBackward>)
# 앞으로도 지금같은 컨디션 계속 유지해주시길 바랄께요^^
# tensor([0.0634, 0.9370], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조용한 곳입니다.
# tensor([0.1441, 0.8558], device='cuda:0', grad_fn=<SigmoidBackward>)
# 정리도 잘 되어있었어요
# tensor([0.0240, 0.9761], device='cuda:0', grad_fn=<SigmoidBackward>)
# 체크인시 직원 안내가 부족했다.
# tensor([0.9556, 0.0378], device='cuda:0', grad_fn=<SigmoidBackward>)
# 한명 들어가 자도될것같다.
# tensor([0.9590, 0.0350], device='cuda:0', grad_fn=<SigmoidBackward>)
# 환기를 더 강하게 할 필요가 있을 듯 합니다.
# tensor([0.9621, 0.0318], device='cuda:0', grad_fn=<SigmoidBackward>)
# 히노끼탕이 좋고 위치도 좋아요
# tensor([0.0347, 0.9654], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청소상태가 좋지 않은 듯
# tensor([0.9570, 0.0375], device='cuda:0', grad_fn=<SigmoidBackward>)
# 생각했던 것보다 내부가 좁고 에어컨이 시끄럽습니다.
# tensor([0.9370, 0.0572], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1인실이 있단 이유만으로 숙박을 결정했는데 혼자서 지내기에 불편함이 없었습니다.
# tensor([0.0361, 0.9616], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 높은 층이라고 야경을 기대해서는 절대 안된다 주변 건물들이 다 철물점 페인트가게 그런것들로 가득 차있다.
# tensor([0.9225, 0.0691], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 체크아웃 할때 직원의 퉁명스러운 태도 에 또 한번 놀램 앞으로 이호텔에서 숙박 할 것 같지은 않습니다.
# tensor([0.9637, 0.0304], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 관리가 잘 안되었던 점이 아쉬웠습니다.
# tensor([0.9564, 0.0380], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가격에 비해 매우매우 좋았고 시설도 깔끔했습니다.
# tensor([0.0284, 0.9715], device='cuda:0', grad_fn=<SigmoidBackward>)
# 모던하고 세렴된 디자인의 객실로 깨끗하고 안락 했으며 객실바닥이 원목과 타일인 점이 매우 만족스러웠습니다.
# tensor([0.0254, 0.9749], device='cuda:0', grad_fn=<SigmoidBackward>)
# 욕조는 아담하니 좋았는데 청소상태가 조금아쉬웠구요 ,
# tensor([0.9589, 0.0360], device='cuda:0', grad_fn=<SigmoidBackward>)
# 거실이 생각보다 작앗습니다.
# tensor([0.9634, 0.0299], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결도에 대해서도 저는 좋은 점수를 드릴수가 없겠습니다
# tensor([0.9591, 0.0348], device='cuda:0', grad_fn=<SigmoidBackward>)
# 출장 갈 때마다 이용하는데 가성비 완전 좋아요.
# tensor([0.0779, 0.9210], device='cuda:0', grad_fn=<SigmoidBackward>)
# 티비 쪽 벽지가 울어있어서 낮에 티비 볼 때는 신경이 쓰였어요 ㅠㅠㅠ
# tensor([0.9626, 0.0317], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조용하고 편안해요.
# tensor([0.0596, 0.9399], device='cuda:0', grad_fn=<SigmoidBackward>)
# 군더더기 없는 깔끔한 숙소에요.
# tensor([0.0317, 0.9687], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸 컨디션은 좋습니다.
# tensor([0.0482, 0.9502], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 위치가 좋습니다
# tensor([0.0508, 0.9496], device='cuda:0', grad_fn=<SigmoidBackward>)
# 욕실에 물때나 먼지같은 청결이 아쉬웠어요 ㅠ
# tensor([0.9081, 0.0845], device='cuda:0', grad_fn=<SigmoidBackward>)
# 어메니티도 1박마다 채워주지 않는다.
# tensor([0.9339, 0.0567], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수건이나 침구커버에서 표백제냄새가 있었고 욕조나 샤워시설이 보기에만 깔끔해 보일뿐 실용적이지못하고 불편합니다
# tensor([0.9441, 0.0500], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이 닦는데 자꾸 휘어요 ㅠㅠ
# tensor([0.9647, 0.0293], device='cuda:0', grad_fn=<SigmoidBackward>)
# 건조해서 가습기 부탁해서 머무는 동안 편안히 있었어요.
# tensor([0.0395, 0.9600], device='cuda:0', grad_fn=<SigmoidBackward>)
# 코로나 때문에 조심스럽게 다녔는데 호텔에 사람도 별로 없고 열체크나 이런것도 잘됐어용
# tensor([0.0216, 0.9788], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1.한강뷰를 배정해 주셔서 도시뷰보다 심적인 힐링에 도움을 주었어요.
# tensor([0.0265, 0.9737], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다녀와서 병을 얻어와서 기분은 안좋네요
# tensor([0.9664, 0.0273], device='cuda:0', grad_fn=<SigmoidBackward>)
# 2. 처음 객실에서 계속해서 들려오는 미세한 소음이 있어 프론트직원분께 말씀드렸더니 즉각적으로 대응해주셨습니다.
# tensor([0.1332, 0.8644], device='cuda:0', grad_fn=<SigmoidBackward>)
# 편의점이 멀다
# tensor([0.9679, 0.0262], device='cuda:0', grad_fn=<SigmoidBackward>)
# 15층은 창밖 풍경이 좋은 편입니다.
# tensor([0.8323, 0.1589], device='cuda:0', grad_fn=<SigmoidBackward>)
# 서울대병원이용하기 좋아요
# tensor([0.0595, 0.9413], device='cuda:0', grad_fn=<SigmoidBackward>)
# 배개가 너무 푹신해서 배다보면은 얇아지는게 조금 아쉬웠습니다.
# tensor([0.9415, 0.0522], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 좀 불편했어요.
# tensor([0.8558, 0.1399], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결하고 예뻤어요 ~~
# tensor([0.0372, 0.9626], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장, 사우나 시설 좋음. 직원들이 친절하고 서비스가 좋았음. 주변에 이용할 수 있는 식당이 많았고 또 필요시 취사에 편리. 지하철 5호선이 가까움.
# tensor([0.0293, 0.9710], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 조금 기다려야 차가 나온다는 점이 불편했지만, 차를 바로 타야 하는 분은 미리 말씀드리면 직원분이 친절하게 빼주실거에요 ㅎㅎ
# tensor([0.9176, 0.0771], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지내는 동안 정말 감사했습니다.
# tensor([0.0956, 0.9027], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 편리함
# tensor([0.0613, 0.9370], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사실 이런저런 단점이 있고 방이 작아 부모님이 안좋아하셨지만 저는 뭐 가성비좋게 짧게 하루 잘 지냈다고 생각합니다.
# tensor([0.0311, 0.9675], device='cuda:0', grad_fn=<SigmoidBackward>)
# 결론적으로는 잘 이용하다가 나왔지만요.
# tensor([0.9453, 0.0471], device='cuda:0', grad_fn=<SigmoidBackward>)
# 컨디셔너도 있었는데 컨디셔너 쓰면서도 이게 내가 제대로 쓰고있는건지 이름 계속 봤어요
# tensor([0.0325, 0.9684], device='cuda:0', grad_fn=<SigmoidBackward>)
# 온수가 정말 안나옴 누가 쓰면 내가 찬물 나옴. 충전코드가 침대에 가려져 있음. 도심속이라 지하철은 좋지만 자가용등은 안 좋응
# tensor([0.9670, 0.0274], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음이 아쉽군요
# tensor([0.9573, 0.0355], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원분들 친절하시구 객실 깔끔했습니다
# tensor([0.0843, 0.9129], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치적으로 모든게 편리했어요
# tensor([0.0780, 0.9205], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 너무 편하고 침구가 안락했어요
# tensor([0.0368, 0.9635], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들 응대. 1.현관에 차를 잠깐 세워놓고 체크인만 해야하는 상황이 발생하였는데 휴대폰만 들여다 보고 있던 상급자같은 직원이 차를 다 세우고 문열고 나오려는데 여기 세우면 안된다는 불평섞인 말투로 다시 세우라 함. 차들어 오는 순간 예의 주시하고 있다가 가이드 해야 하는 것임. 2.최초 2박 예약을하고 투숙을 했는데 마지막 날 아침 10시부터 객실 문옆 판낼 공사를 하여 아침 시간에 방해받음...전날이나 투숙전에 이 사실을 주지시켜 주던지 공사가 없는 방으로 안내를 해야하는데 하루를 더 연장하여 투숙하게 되었는데도 또 그 다음날 공사가 있었음에도 같은 방에 투숙이 연장되어 또 아침 시간 소음으로 불편 했음. 3.3일간 투숙하면서 차를 한번도 출차하지 않고 지하 주차장에 두었는데 체크아웃 하면서 차량의 무이동 주차상황을 얘기했음에도 불구. 적절한 주차권 준비를 해주질 않아 바쁘게 나가는 길에 직원이 지하주차장까지 오는데 기다림. 비지니스 호텔임에도 불구하고 업무차 투숙을 하는 손님에게 상기와 같은 직원들의 응대와 조치는 정상급 비지니스 호텔을 지향하는 GLAD에 의구심을 들게 함. 시설 문제가 아닌 인재이므로 시정과 재교육이 가능할 것으로 사려 합니다.
# tensor([0.9574, 0.0372], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1. 방에 양쪽으로 거울이 있었습니다.
# tensor([0.8764, 0.1156], device='cuda:0', grad_fn=<SigmoidBackward>)
# 굳이 꼽자면 지하철역에서 엄청 가깝지는 않지만 그리 멀지도 않아요 ㅎㅎ
# tensor([0.9267, 0.0636], device='cuda:0', grad_fn=<SigmoidBackward>)
# 실내인테리어가 고급지진 안았어요
# tensor([0.9657, 0.0280], device='cuda:0', grad_fn=<SigmoidBackward>)
# 예약사이트를 이용하면 제일 나쁜 방을 주는건가 하는 생각을 함. 복도 제일 끝의 방, 어이없는 뷰, 의자와 탁자도 없는 협소함.. 충전기도 구비되어 있지 않은 점 등등..
# tensor([0.9537, 0.0403], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 윗쪽에서 뭔가 찧는소리가 2박3일동안 나더군요.
# tensor([0.9452, 0.0485], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음 최악. 매우 저렴한 고시원의 방음 수준.
# tensor([0.9622, 0.0314], device='cuda:0', grad_fn=<SigmoidBackward>)
# 크게는 두배이상 비쌉니다.
# tensor([0.1584, 0.8369], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그 돈으로 차라리 좋은펜션에서 1박하고 좋아하는 캐릭인형을 선물하는게 낫겠어요
# tensor([0.9093, 0.0810], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그런데 그 반대편 뷰를 볼 수 있는 방이어서 그 점이 조금 아쉬웠어요 ㅎㅎ
# tensor([0.3203, 0.6797], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치는 최고네요!!
# tensor([0.0682, 0.9315], device='cuda:0', grad_fn=<SigmoidBackward>)
# 비데 없고 & 생수 너무 비쌈 & 크린징폼 없슴 &
# tensor([0.9564, 0.0374], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 제가 물건을 놓고 온것 같은데 별도 연락도 안주시더라구요.
# tensor([0.9370, 0.0563], device='cuda:0', grad_fn=<SigmoidBackward>)
# 프런트의 기분좋은 응대에 감사드립니다.
# tensor([0.0562, 0.9437], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 매우 좋았어요
# tensor([0.0409, 0.9589], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치는 좋았고, 아침은 간단히 먹기에는 적절했습니다.
# tensor([0.0408, 0.9591], device='cuda:0', grad_fn=<SigmoidBackward>)
# 서울역 바로옆, 접근성이 매우 좋음. 청결함
# tensor([0.0297, 0.9702], device='cuda:0', grad_fn=<SigmoidBackward>)
# 하 아침부터 엄청 시끄러움.. 참고하세여
# tensor([0.9591, 0.0346], device='cuda:0', grad_fn=<SigmoidBackward>)
# 일회용품의 부재. 시설대비 비싸다
# tensor([0.9683, 0.0258], device='cuda:0', grad_fn=<SigmoidBackward>)
# 저희가 선택한 패키지의 조식 구성이 일반적이지 않았던 것인지, 코로나의 영향인지 모르겠지만 한식 메뉴가 있다고 생각했는데 닭 죽을 제외한 한식은 없었습니다.
# tensor([0.3513, 0.6354], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오후 6시에만 들어가야하는 늦은 체크이인였고 부킹닷컴 지니어스라 얼리체크인 부탁했는데 평일인데도 불구하고 3시간 기다렸음
# tensor([0.9621, 0.0319], device='cuda:0', grad_fn=<SigmoidBackward>)
# 실내수영장 크기가 그리 크지는 않지만 평일이여서 그런가 저희 빼고 3커플 정도 밖에 없어서 딸아이가 좋아하는 수영을 원없이 하고 왔습니다.
# tensor([0.5791, 0.4245], device='cuda:0', grad_fn=<SigmoidBackward>)
# 친절하고 너무 만족스러운 숙소였습니다~ 다음에 또 가고싶어요^^
# tensor([0.0870, 0.9139], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그런 공지사항이 없었어서 아쉬움. 가격대비 만족도는 그럭저럭임.
# tensor([0.9441, 0.0496], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전체적인 직원응대가 미흡한 느낌이었습니다.
# tensor([0.9516, 0.0425], device='cuda:0', grad_fn=<SigmoidBackward>)
# 커피머그만 3개 .. 와인잔과 포크는 요청하니 받을 수 있었다.
# tensor([0.2257, 0.7749], device='cuda:0', grad_fn=<SigmoidBackward>)
# 최근 건물이라 깨끗함. 침대 룸 컨디션 좋음. 잠만 잔 곳이라 세밀한 평가가 어려움
# tensor([0.0483, 0.9493], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방안이 건조 하다.
# tensor([0.9633, 0.0309], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 매우 편안했고 미리 요청드린 메모리폼 베개도 준비되어 있어서 기분이 좋았습니다
# tensor([0.0294, 0.9709], device='cuda:0', grad_fn=<SigmoidBackward>)
# 푹신푹신 호텔자체가 너무 예쁘고 정말 외국느낌이라서 재밋게 잘 지냈습니다!
# tensor([0.0466, 0.9538], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아이스링크 프로포즈로 객실 예약했는데 기대이상으로 좋았습니다.
# tensor([0.0303, 0.9700], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실 샤워부스가 통 유리이고, 그쪽을 미닫이 가벽으로 막아둔 형태라 화장실도 전혀 방음이 안 되어요
# tensor([0.9472, 0.0460], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결도가 떨어짐. 침대밑에 쓰레기들, 먼지가득
# tensor([0.9376, 0.0538], device='cuda:0', grad_fn=<SigmoidBackward>)
# 넓었고 편안했어요
# tensor([0.0649, 0.9345], device='cuda:0', grad_fn=<SigmoidBackward>)
# 피트니스등 라운지 규모/퀄리티
# tensor([0.0346, 0.9644], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그냥 나가기만 하면 되나요?
# tensor([0.8468, 0.1477], device='cuda:0', grad_fn=<SigmoidBackward>)
# 공항과 가까워 편리했어요.
# tensor([0.0556, 0.9444], device='cuda:0', grad_fn=<SigmoidBackward>)
# 정문이 자동이 아니더라고요
# tensor([0.9096, 0.0838], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아침에 일어나서 욕조를 사용했는데 야외 콘서트를 보고 무거워진 몸이 단번에 가뿐해졌답니다.
# tensor([0.6704, 0.3201], device='cuda:0', grad_fn=<SigmoidBackward>)
# 밤에 잘려고 하는데 옆 방 소리 들림.
# tensor([0.9540, 0.0393], device='cuda:0', grad_fn=<SigmoidBackward>)
# 피자국도 있고...
# tensor([0.0398, 0.9591], device='cuda:0', grad_fn=<SigmoidBackward>)
# 고요해서 좋았습니다
# tensor([0.0529, 0.9467], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 남산뷰도 좋고 재방문의사 있어요
# tensor([0.0373, 0.9632], device='cuda:0', grad_fn=<SigmoidBackward>)
# 내가 이런꼴 안보려고 싸구려 숙소말고 호텔잡은건데 체크아웃 전에 기분 망쳐놓네요.
# tensor([0.8500, 0.1414], device='cuda:0', grad_fn=<SigmoidBackward>)
# 투숙객이 많지 않아서 내부는 모르겠지만 외부소리가 들려요
# tensor([0.9558, 0.0364], device='cuda:0', grad_fn=<SigmoidBackward>)
# 실내화랑 도미인 홈웨어로 호텔 전부를 다닐수 있는것도 은근히 편하더라구요~ 밤 9시반부터 무료로주는 라멘도 좋았고 무엇보다도 조식이 좋았어요~ 먹을게 많더라구요
# tensor([0.0266, 0.9738], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방문객이나 일행이 있는데 주차가 1대뿐이라는 점도 레지던스 특성상 좀.. 물론 해주긴 하셨지만 번거롭긴 했네요.
# tensor([0.9460, 0.0480], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 좋고 방과 욕실이 넓어요
# tensor([0.0346, 0.9659], device='cuda:0', grad_fn=<SigmoidBackward>)
# 보통 만점(10)을 주는 경우가 없으나, 이번 호텔은 전반적으로 매우 만족스러웠습니다.
# tensor([0.0379, 0.9601], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가족들끼리 집처럼 사용할 수 있어서 좋았음
# tensor([0.0245, 0.9757], device='cuda:0', grad_fn=<SigmoidBackward>)
# 티슈가 욕실에만 있었는데 침대맡에도 배치되어있으면 좋겠어요
# tensor([0.9345, 0.0580], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장이 투숙객 무료인지라 관리가 잘 안된다는 느낌입니다
# tensor([0.9240, 0.0679], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 맛있다
# tensor([0.0446, 0.9545], device='cuda:0', grad_fn=<SigmoidBackward>)
# 투숙객에게 사우나 이용료를 받는게 ㅠㅠ 아쉽구요
# tensor([0.8861, 0.1062], device='cuda:0', grad_fn=<SigmoidBackward>)
# 무료셔틀과 웰컴 드링크 서비스가 좋았어요^^
# tensor([0.0261, 0.9740], device='cuda:0', grad_fn=<SigmoidBackward>)
# 쇼파도 너무 오래됐고, 딱 보면 모텔같은 느낌 ㅠ 리모델링이 필요할 거 같아요.
# tensor([0.9290, 0.0629], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이런 문이 방화문의 역할은 제대로 될런지 의문이 들었습니다.
# tensor([0.9132, 0.0781], device='cuda:0', grad_fn=<SigmoidBackward>)
# 생각보다는 객실이 좁았어요
# tensor([0.9431, 0.0529], device='cuda:0', grad_fn=<SigmoidBackward>)
# 건너편에 브런치카페가 있는데 분위기도 좋고 맛도 있었습니다.
# tensor([0.0273, 0.9729], device='cuda:0', grad_fn=<SigmoidBackward>)
# 온풍기가 너무 건조해서 피부가 마르는 느낌이 들었음 체크인 기계가 있지만 처음해보는 시스템이라 어색했음
# tensor([0.5964, 0.3962], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오죽하면 밤에 전화를 걸어서 담배냄새가 너무 난다고 말했습니다...
# tensor([0.9357, 0.0562], device='cuda:0', grad_fn=<SigmoidBackward>)
# 스위트 투윈룸 전망은 전혀 없어서 많이 아쉬웠다
# tensor([0.9573, 0.0357], device='cuda:0', grad_fn=<SigmoidBackward>)
# 외출할 때 카드를 맡기고 갔는데 들어와서 문의해서 바로 못 찾았었어요. ^^
# tensor([0.9429, 0.0514], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식이용은 못했습니다..
# tensor([0.2686, 0.7235], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지나다니는 사람들 소리가 다 들림.
# tensor([0.9627, 0.0311], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다음에 이용할 생각입니다.
# tensor([0.1437, 0.8533], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치도 좋고 깨끗하고 편안하게 잘 묵었습니다!
# tensor([0.0958, 0.9054], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구정리도 깔끔하고 쾌적하고 좋습니다
# tensor([0.0533, 0.9477], device='cuda:0', grad_fn=<SigmoidBackward>)
# 3박을 머물렀는데 직원분들도 너무 친절하셨어요
# tensor([0.0779, 0.9176], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실 준비가 길어져 체크인이 예정보다 늦어졌는데, 레이트 체크아웃 서비스를 받게되어 좀 더 여유롭고 편안히 쉴 수 있었습니다.
# tensor([0.0254, 0.9745], device='cuda:0', grad_fn=<SigmoidBackward>)
# 세면대 물이 잘 안내려갔습니다
# tensor([0.6444, 0.3538], device='cuda:0', grad_fn=<SigmoidBackward>)
# 창문밖이 바로 옆 빌딩이라 창문을 열지도 못하고 항상 커텐을 친채로 지내서 딥답했다.
# tensor([0.9586, 0.0352], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸서비스를 시켰을 때는, 룸서비스를 해주시는 분의 복장과 태도가 엉망이었습니다.
# tensor([0.9616, 0.0324], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1. 그릇, 컵이 닦여있지 않았습니다.
# tensor([0.9687, 0.0263], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1층 무료 카페테리아 시간이 정오부터 자정까지여서 아침 커피를 못 마심. 결국 한번도 못 마심.
# tensor([0.9336, 0.0611], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그 외엔 모든 게 좋았습니다.
# tensor([0.7845, 0.2037], device='cuda:0', grad_fn=<SigmoidBackward>)
# 신라 스테이 마포 오픈한지 5년 정도 된 걸로 알고 있는데 벽지가 금 간 것처럼 그렇게 떠 있는 걸 봐서 좀 충격이었어요
# tensor([0.8244, 0.1638], device='cuda:0', grad_fn=<SigmoidBackward>)
# 4성급인 이유는 위치가 좋기 때문에 4성급인가라는 생각을 했고 위치를 제외한 나머지는 3성급 호텔보다도 실망했네요..
# tensor([0.9633, 0.0313], device='cuda:0', grad_fn=<SigmoidBackward>)
# 초역세권이고 출장 차 숙박하기에 정말 좋아요.
# tensor([0.0250, 0.9756], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 블라인드 물때도 한 번 점검해주셔야 할 것 같아요.
# tensor([0.8877, 0.1052], device='cuda:0', grad_fn=<SigmoidBackward>)
# 특히 욕실이 생각했던 것보다 사이즈가 너무 작았고 욕실 문이 여닫이로 되어 있는데 손잡이랑 벽 위치가 맞지 않아서 몇 번이나 껴어서 다쳤네요..
# tensor([0.9020, 0.0903], device='cuda:0', grad_fn=<SigmoidBackward>)
# 많이 붐비지 않고 편안한 분위기였어요
# tensor([0.0383, 0.9618], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 주변에 대중교통을 이용하기에 편하고, 1층에 있는 '커피스미스' 카페도 가까워서 맛있는 커피를 아침에 마실 수 있어서 행복했습니다^^
# tensor([0.0376, 0.9633], device='cuda:0', grad_fn=<SigmoidBackward>)
# 친구들과의 숙박이었는데, 너무 오랜만에 묵었지만 그래도 변함없는 숙박이 너무 좋았습니다.
# tensor([0.0341, 0.9660], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음이 전혀 안됨. 앞방인지 옆방인지 매우 시끄러웠음. 청결하기는 하나 깨끗한 인상을 받지 못함
# tensor([0.9562, 0.0368], device='cuda:0', grad_fn=<SigmoidBackward>)
# 베이커리가 맛없어요
# tensor([0.9398, 0.0518], device='cuda:0', grad_fn=<SigmoidBackward>)
# 쾌적하고 편리했습니다,.
# tensor([0.1368, 0.8643], device='cuda:0', grad_fn=<SigmoidBackward>)
# 복도가 좁았어요
# tensor([0.9674, 0.0271], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식은 굳이 추천하지 않아요
# tensor([0.4845, 0.5157], device='cuda:0', grad_fn=<SigmoidBackward>)
# 혜화역과 가깝고 종로도 가까워서 위치는 만족스러웠ㅇㅓ요 방 크기는 조금 작아서 아쉬웠지만 포근하고 화장실은 생각보다 작지 않아서 대체적으로 만족스러운 숙박이었습니다.
# tensor([0.0354, 0.9641], device='cuda:0', grad_fn=<SigmoidBackward>)
# 근처에 밥먹을곳이 마땅치는 않아서 다른곳으로 나가시는걸 추천합니다
# tensor([0.9577, 0.0350], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 카페가 너무 좁고 테이블이 몇 개 없음. 가족 단위 여행에는 비추. 직원들은 무뚝뚝함. 방향제 냄새가 거북하고 겨울에는 실내 온도가 낮은 편임. 실내가 어두움. 샤워실이 노출되어 있고 화장실이 안 잠기기 때문에 주의해야 함. 복도 소음이 있고 청소하는 직원이 이용하는 카트의 바퀴 굴러가는 소리다 다 들림. 복도에서 담배냄새가 남.
# tensor([0.9655, 0.0290], device='cuda:0', grad_fn=<SigmoidBackward>)
# 핫플레이스 앞이라 밤에 아주 조용하지는 않아요
# tensor([0.9102, 0.0787], device='cuda:0', grad_fn=<SigmoidBackward>)
# 엘리베이터 바로 앞이었는데도 그닥 시끄럽지 않았고, 객실도 생각보다 넓었습니다.
# tensor([0.0219, 0.9783], device='cuda:0', grad_fn=<SigmoidBackward>)
# 로비와복도만 좋았네요
# tensor([0.3555, 0.6390], device='cuda:0', grad_fn=<SigmoidBackward>)
# 고객 요청사항에도 친절히 응대해주시고 청결한 룸 상태도 정말 좋았어요!
# tensor([0.0403, 0.9596], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 위치 좋아서 커플이 사용 하기렌 참 좋습니다
# tensor([0.0704, 0.9295], device='cuda:0', grad_fn=<SigmoidBackward>)
# 냄새빼고는 다 좋았어요.
# tensor([0.8522, 0.1339], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구가 아늑하고 따뜻했습니다.
# tensor([0.0492, 0.9512], device='cuda:0', grad_fn=<SigmoidBackward>)
# 옆방인지 윗방인지 모르겠으나 대화 소리가 다 들릴 정도였어요
# tensor([0.9554, 0.0378], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아쉬운 점 없음요..
# tensor([0.9711, 0.0241], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 메뉴가 많이 식어있었습니다
# tensor([0.9648, 0.0297], device='cuda:0', grad_fn=<SigmoidBackward>)
# 저희는 너무 더웠어요.
# tensor([0.9481, 0.0457], device='cuda:0', grad_fn=<SigmoidBackward>)
# 창문 환기로 문을 열면 주변 공사장 소음 그러나 위치가좋기때문에 적당
# tensor([0.9192, 0.0738], device='cuda:0', grad_fn=<SigmoidBackward>)
# 담배냄새나고 바닥은 끈적이고 좁고 딱 모텔수준 모텔에 비하면 비쌈
# tensor([0.9063, 0.0860], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구가 조금 눅눅? 했지만 불편하진 않았어요
# tensor([0.9492, 0.0446], device='cuda:0', grad_fn=<SigmoidBackward>)
# 좋은 추억을 남기고 갑니다.
# tensor([0.0339, 0.9650], device='cuda:0', grad_fn=<SigmoidBackward>)
# 겨울시즌은 발렛 파킹 차 기다리는 소요시간을 조금 더 단축 될수 있었으면 퍼펙트한 호캉스였을것 같아요
# tensor([0.9480, 0.0458], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 맘에 들었습니다.
# tensor([0.0306, 0.9693], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호텔에 편의점이 있고 역에서 가깝습니다
# tensor([0.0336, 0.9663], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치 좋고 깔끔하고 편안한 인테리어에 편하게 쉬었습니다
# tensor([0.0869, 0.9137], device='cuda:0', grad_fn=<SigmoidBackward>)
# 원래 후기 자체를 거의 남기지 않는데 이번엔 좀 상세하게 남겨봄. 그간 서울서 호캉스를 왜 하는지 궁금하였기에, 시도해봤는데 뭔가 어쩡정한 경험이었음. 0. 시청역 혹은 충정로역에서 한참 걸어야 함. 1. 체크인 때, 돈 더 내고, 룸 업그레이드 권유 받음. 저렴한 가격으로 권유한 것도 아니고, 부킹닷컴서 이미 봤던 방 가격 그대로 부르길래 기분이 좋지 않았음. 종종 빈방 있으면 무료로 업그레이드 해주는 일은 겪어봤지만, (또 내심 그런 일을 기대했지만), 돈 더 내고 좋은 방 가보란 권유는 처음. 후기 보면 그냥 업그레이드 해준 경우도 보이던데.
# tensor([0.9417, 0.0525], device='cuda:0', grad_fn=<SigmoidBackward>)
# 홍대로 가면 또 방문하고 싶네요
# tensor([0.1041, 0.8980], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깨끗하고 조용함.
# tensor([0.0603, 0.9383], device='cuda:0', grad_fn=<SigmoidBackward>)
# 개선 좀 해줬으면 좋겠습니다.
# tensor([0.9384, 0.0547], device='cuda:0', grad_fn=<SigmoidBackward>)
# 뚜스뚜스 굿 교통 굿! 지하철역, 버스 .. 인테리어 굿
# tensor([0.0307, 0.9694], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아주 오래전에 묵었고 세월이 많이 지났는데도 관리를 잘해서 여전히 깨끗하고 편하게 지내다 왔습니다.
# tensor([0.0461, 0.9533], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방안에서 보는 전망이 이게 나만이 가질수 있는 전망이라 진짜 너무 행복했어요.
# tensor([0.0245, 0.9760], device='cuda:0', grad_fn=<SigmoidBackward>)
# 삶은 계란, 작은 빵 두개, 사과, 바나나, 우유, 쥬스가 들어있었는데 구성이 기대 이하였다.
# tensor([0.9596, 0.0343], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청결하고 침대가 커서 좋았어요
# tensor([0.0298, 0.9706], device='cuda:0', grad_fn=<SigmoidBackward>)
# ...
# tensor([0.0385, 0.9615], device='cuda:0', grad_fn=<SigmoidBackward>)
# 생각보다 좁고 화장실 문 여는 순간 하수구 냄새 올라옴 세면대 및 카펫트에는 먼지와 물기가 그대로 남아있음 애매니티 놓인 곳은 물로 흥건했음 코로나로 일부러 호텔로 쉬러간 것 인데 룸서비스 조차이용이 안됌 이런건 처음부터 유의사항에 게시를 해야하는 것이 기본인데 그조차 명시되지 않았음 사진에 속았음 다신 안감 주변 사람들한테도 절대 추천의사 없음
# tensor([0.9532, 0.0403], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전화를 너무 안받고, 체크인 리드타임이 길고, 룸은 깨끗한데 충전케이블이 없거나 어메니티가 떨어지는 점이 별로였음. 또한 그릴앤바의 직원들 서비스 마인드가 너무 부족함
# tensor([0.9672, 0.0271], device='cuda:0', grad_fn=<SigmoidBackward>)
# 어매니티에 칫솔, 치약, 빗이 없어요
# tensor([0.9586, 0.0343], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방에들어가니 현재온도가 33도였던점.. 온도를 낮추느라 창문을열어서 미세먼지가 다들어와서 힘들었네요
# tensor([0.9528, 0.0412], device='cuda:0', grad_fn=<SigmoidBackward>)
# 충전하려면 로비에 맡겨야 한대서 그게 쪼금...ㅎ
# tensor([0.9588, 0.0364], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구류는 언제나 좋습니다.
# tensor([0.3310, 0.6622], device='cuda:0', grad_fn=<SigmoidBackward>)
# 우선 숙소 위치가 좋고 주변 먹거리(서울역 **아울렛에 계절밥상 추천드려요) 관광 쇼핑(계절밥상 대기자가 많아서 예약 걸고 1시간 쇼핑하고 먹음-음식이 맛있어 기다린 보람 있더라구요)을 즐기기 좋았어요!
# tensor([0.0335, 0.9664], device='cuda:0', grad_fn=<SigmoidBackward>)
# 숙소가 너무 깨끗했어요 !!
# tensor([0.0538, 0.9467], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장물이 차서 애기들이 놀기는 조금 힘들었는데 대신 온수가 따로 있어서 중간중간 몸 뎁히면서 놀앗어요...
# tensor([0.1222, 0.8781], device='cuda:0', grad_fn=<SigmoidBackward>)
# 성인도 아이도 똑같은 추가 요금을 받는 부분은 상당히 불쾌하고 기분이 좋치가 않네요
# tensor([0.9495, 0.0444], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방 크기가 생각보다 작아요
# tensor([0.9619, 0.0327], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사진보고 뷰가 너무 이뻐서 갔는데 고층요청드렸더니 최고층으로 배정해주셔서 예쁜뷰 볼수있었어요
# tensor([0.0307, 0.9693], device='cuda:0', grad_fn=<SigmoidBackward>)
# 시기가 시기인만큼 여러면에서 아쉽군요.
# tensor([0.9375, 0.0548], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아쉬웠던 점은 없습니다
# tensor([0.9673, 0.0268], device='cuda:0', grad_fn=<SigmoidBackward>)
# 익선동 한옥거리와 가까워서 구경할 거리가 많아서 좋았어요.
# tensor([0.0360, 0.9639], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실 간 문 여닫는 소음이 크다.
# tensor([0.9677, 0.0271], device='cuda:0', grad_fn=<SigmoidBackward>)
# 코로나 때문에 조식뷔폐에서 도시락으로 바뀐점은 매우 아쉬웠습니다.
# tensor([0.8612, 0.1275], device='cuda:0', grad_fn=<SigmoidBackward>)
# -예약할 당시 조식이 11,000원이라 돼 있었으나, 막상 호텔에 와서보니 4월1일부터는 25,000원으로 바뀌었고 전날자정까지는 19,800원에 구입이 가능했지만, 이 바뀐조식정보를 예약할 당시라던가 메일로 미리 통지를 해주셨으면 좋았을것 같다
# tensor([0.9447, 0.0493], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가성비가 상당히 낮군요.
# tensor([0.9649, 0.0309], device='cuda:0', grad_fn=<SigmoidBackward>)
# 숙소가 청결하다는 말이 많았는데 벽에 물티슈인지 물이 묻은 휴지인지 손바닥 길이 정도되는게 붙어있었고, 화장실 변기는 사용후 물을 내리지 않았음. 결국 청소가 안된상태였음 방붙은 화장지는 사진으로 증거 남김
# tensor([0.9508, 0.0428], device='cuda:0', grad_fn=<SigmoidBackward>)
# 새 건물이라 깨끗했고, 인테리어에 신경을 쓴 게 보입니다.
# tensor([0.0241, 0.9759], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호크니 전시회를 관람하고 날씨가 너무 더워서 2시간정도 일찍 체크인을 하는데도 무척 친절하게 응대해주셨고, 사전에 예약할 때 담배냄새 나지 않는 객실을 요구하였는데 마지막까지 꼼꼼하게 체크해주신 점이 좋았습니다.
# tensor([0.0225, 0.9780], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방음이 부족합니다.
# tensor([0.9511, 0.0406], device='cuda:0', grad_fn=<SigmoidBackward>)
# 진드기 덕분인지 자고나서 몸이 심하게 가렵고 따가왔다.
# tensor([0.9640, 0.0299], device='cuda:0', grad_fn=<SigmoidBackward>)
# 요청사항에 적어놓은 공기청정기가 처음으로 준비 안되었습니다
# tensor([0.9633, 0.0305], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전망과 잠자리가 편했습니다.
# tensor([0.0245, 0.9755], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 넘 좋고 이불빼고는 넘 좋았어요..
# tensor([0.1555, 0.8404], device='cuda:0', grad_fn=<SigmoidBackward>)
# 도심 한복판에 있는데 주차비가 너무 비싸요 입구도 좀 더 뚜렷하게 표시 해주시면 좋겠어요
# tensor([0.9166, 0.0766], device='cuda:0', grad_fn=<SigmoidBackward>)
# 공휴일이라 사람이 많았음에도 불구하고 호텔이어 분들께서 굉장히 친절하시고 상황을 유도리 있게 판단하셔서 불편함 없이 시스템을 잘 이용할 수 있도록 해주셨습니다
# tensor([0.0419, 0.9576], device='cuda:0', grad_fn=<SigmoidBackward>)
# 편안한 베드와 군더더기없는 시설도 마음에 들었습니다. 가성비 좋아요.
# tensor([0.0380, 0.9626], device='cuda:0', grad_fn=<SigmoidBackward>)
# 사람이 없어 혼자 썼습니다.
# tensor([0.0523, 0.9443], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸 콘디션은 깔끔한 편입니다.
# tensor([0.0854, 0.9099], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깔끔하고 공기청정기까지 구비
# tensor([0.0299, 0.9699], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치짱 흠잡을게 없네요!
# tensor([0.0254, 0.9750], device='cuda:0', grad_fn=<SigmoidBackward>)
# 판매 상품이 조금만 더 다양하면 좋을 것 같습니다.
# tensor([0.0845, 0.9169], device='cuda:0', grad_fn=<SigmoidBackward>)
# 프리미어 스위트룸에 묵었는데, 욕조가 작아서 아쉬웠습니다.
# tensor([0.9448, 0.0497], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청소 아주머니께 깨끗히 청소를 요청했으나, 청소후에도 악취가 가시지 않았다.
# tensor([0.9337, 0.0604], device='cuda:0', grad_fn=<SigmoidBackward>)
# 고시원?같은 건물을 그냥. 레지던스로 운영 하는 건물인데.
# tensor([0.9575, 0.0359], device='cuda:0', grad_fn=<SigmoidBackward>)
# 잘 안닦인듯 뭔가 떨어져 마른듯한 얼룩이 군데군데 있었습니다~
# tensor([0.9517, 0.0421], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주차장 아쉬움
# tensor([0.9566, 0.0377], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 투고 서비스는 좋았습니다.
# tensor([0.1366, 0.8563], device='cuda:0', grad_fn=<SigmoidBackward>)
# 같은 이상한 사람들이 말을 걸어서 당황했어요
# tensor([0.9568, 0.0361], device='cuda:0', grad_fn=<SigmoidBackward>)
# 2. 비행기 결항 관련 연락을 드렸더니 빠른 대처를 해주셔서 너무 감사했습니다.
# tensor([0.0308, 0.9690], device='cuda:0', grad_fn=<SigmoidBackward>)
# 꼭대기층까지 갔는데 예닐곱번쯤 문열리는 동안 아무도 안탔습니다.
# tensor([0.9370, 0.0546], device='cuda:0', grad_fn=<SigmoidBackward>)
# 휘트니스센터에서 신발과 옷등을 대여해줘서 매우 만족했습니다. 가족들과 보내는 여행으로는 매우 좋은것같고 근처에 석촌호수가 있어서 좋았습니다.
# tensor([0.0281, 0.9720], device='cuda:0', grad_fn=<SigmoidBackward>)
# 직원들은 대체로 친절한 편이었다.
# tensor([0.1235, 0.8714], device='cuda:0', grad_fn=<SigmoidBackward>)
# 객실은 사진과는 전혀 다른 모습이고 악취가 너무 심하고 복도와 객실바닥 엘리베이터엔 손닿으면 바로 병 옮을고같은 더러운 매트들이 깔려있고 호텔 지어진 이후 한번도 레노베이션 없었더라구요.
# tensor([0.9288, 0.0635], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가격대비 널찍해서 들어가자마자 만족! 개인적으로 어두운 조명 싫어하는데 조명도 많고 밝아서 아주 좋았습니다.
# tensor([0.0261, 0.9741], device='cuda:0', grad_fn=<SigmoidBackward>)
# 베개가 높아서 좀불편했어요ㅜ 낮은베개를 따로 요청할수 있었음 좋겠다는생각이들었어요.
# tensor([0.9527, 0.0411], device='cuda:0', grad_fn=<SigmoidBackward>)
# 요즘에는 너무나 훌륭한 모텔이 많기 때문입니다.
# tensor([0.9567, 0.0361], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구가 편해서 숙면을 취할 수 있었어요
# tensor([0.0328, 0.9675], device='cuda:0', grad_fn=<SigmoidBackward>)
# 새벽에 옆방에서 다투는 소리 때문에 잠에서 깰 정도였다.
# tensor([0.8998, 0.0932], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전혀 없음. 굳이 꼽자면 욕조가 없는 것
# tensor([0.9051, 0.0835], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식은 다소 부실했습니다만, 해피아워가 단점을 다 커버했습니다.
# tensor([0.0680, 0.9277], device='cuda:0', grad_fn=<SigmoidBackward>)
# 마침 그날에 지하에 클럽이 새로 오픈하였는데 거의 아침이 될때까지 쿵쾅거리는 진동소리때문에 잠을 못잤습니다
# tensor([0.9327, 0.0596], device='cuda:0', grad_fn=<SigmoidBackward>)
# 가격대비 조금 아쉬운 정도
# tensor([0.9667, 0.0285], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깔끔하고 예뻐서 만족스러웠습니다
# tensor([0.0902, 0.9090], device='cuda:0', grad_fn=<SigmoidBackward>)
# 투더블베드룸 완전편하고 좋았음. 방크기도 넉넉하고 가족과 함께오기에 넘좋은곳인듯함.
# tensor([0.0247, 0.9755], device='cuda:0', grad_fn=<SigmoidBackward>)
# 여름에 테라스 이용하면 좋을꺼 같아요!
# tensor([0.5020, 0.4965], device='cuda:0', grad_fn=<SigmoidBackward>)
# 종류가 다양한건 아니였는데 연어샐러드 너무 맛있어서 2접시나 먹었어요
# tensor([0.0314, 0.9687], device='cuda:0', grad_fn=<SigmoidBackward>)
# 정확히는 화양시장?과 매우 가깝습니다.
# tensor([0.5388, 0.4623], device='cuda:0', grad_fn=<SigmoidBackward>)
# 디럭스더블에 티스푼이 없고 욕실이 어두웠어요
# tensor([0.9560, 0.0374], device='cuda:0', grad_fn=<SigmoidBackward>)
# 통상 이정도면 30분정도면 될거라고 하더군요.
# tensor([0.9072, 0.0872], device='cuda:0', grad_fn=<SigmoidBackward>)
# 치약 칫솔은 제공되지 않습니다!
# tensor([0.9579, 0.0353], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치도 좋은 편이고 , ifc몰과 함께 있어서 쇼핑하기에도 문화생활하기에도 아주 좋았습니다.
# tensor([0.0280, 0.9726], device='cuda:0', grad_fn=<SigmoidBackward>)
# 자신의 방이 조용하면 옆방의 소리가 들려요...
# tensor([0.9630, 0.0309], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방이 작은 편입니다.
# tensor([0.9377, 0.0548], device='cuda:0', grad_fn=<SigmoidBackward>)
# 화장실이 너무 협소하여 씻는데 불편함이 있었습니다
# tensor([0.9625, 0.0317], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아무래도 골목에 위치하니 근처 밤길 좀 무서워요
# tensor([0.9651, 0.0293], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조용하다 침구는 푹신 화장실도 깨끗
# tensor([0.0323, 0.9677], device='cuda:0', grad_fn=<SigmoidBackward>)
# 룸서비스를 주문하였으나 원하는 상품이 준비가 되어 있지 않아서 아쉬웠습니다.
# tensor([0.9655, 0.0298], device='cuda:0', grad_fn=<SigmoidBackward>)
# 체크인 대기시간이 너무 길었습니다
# tensor([0.9556, 0.0378], device='cuda:0', grad_fn=<SigmoidBackward>)
# 최고의 위치에 있어서 좋아요
# tensor([0.0675, 0.9318], device='cuda:0', grad_fn=<SigmoidBackward>)
# 투숙객은 2층 카페에서 20프로 할인 해줘서 좋다.
# tensor([0.0919, 0.9065], device='cuda:0', grad_fn=<SigmoidBackward>)
# 난방을 켜도 온도가 잘 안 올라가서 그 방을 제외한 다른 방에서 자야만 했습니다.
# tensor([0.9483, 0.0455], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치 및 가성비가 최고 입니다.
# tensor([0.0533, 0.9463], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1층에서 맞이하는 직원이 있을때도 있고 없을때도 있었습니다.
# tensor([0.8654, 0.1271], device='cuda:0', grad_fn=<SigmoidBackward>)
# 찾기 힘들어요 ㅋㅋ
# tensor([0.9628, 0.0319], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아주 깨끗하고 사우나와 수영장 시설도 사람이 많지 않고 생각보다 넓어서 아주 맘에 들었습니다.
# tensor([0.0294, 0.9712], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 이용이 아쉬웠습니다.
# tensor([0.9648, 0.0303], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치가 너무 좋았어요
# tensor([0.0374, 0.9629], device='cuda:0', grad_fn=<SigmoidBackward>)
# 약간 아쉽습니다.
# tensor([0.7606, 0.2405], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지난번에 조식 이용에 아쉬움을 느껴서 이번에 이용하지 않음
# tensor([0.9133, 0.0774], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전망. 주변상권 .야경
# tensor([0.0529, 0.9476], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방이 너무 건조해서 히터를 꺼야하나 해서 히터를 끄고 잤는데도 방이 너무 건조했어요
# tensor([0.8711, 0.1205], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장, 숙소, 직원들 친절함, 넓은 객실.. 다 좋았습니다.
# tensor([0.1347, 0.8615], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그외에 필요한 기본 어매니티들이 잘 갖춰져있어서 불편함은 못느꼇습니다.
# tensor([0.9652, 0.0285], device='cuda:0', grad_fn=<SigmoidBackward>)
# 엄마와1박했는데 모든것이만족스러웠습니다.
# tensor([0.0249, 0.9748], device='cuda:0', grad_fn=<SigmoidBackward>)
# 지금껏 많은 서울 호텔들을 경험해봤지만 이만한 가성비 좋은 호텔은 없었어요!
# tensor([0.1379, 0.8508], device='cuda:0', grad_fn=<SigmoidBackward>)
# 샤워실에서 좀 담배냄새가 나는 거 같았습니다.
# tensor([0.9146, 0.0777], device='cuda:0', grad_fn=<SigmoidBackward>)
# 청량리역까지 정말 가까워서 부담없이 편히 자고 왔습니다.
# tensor([0.0337, 0.9665], device='cuda:0', grad_fn=<SigmoidBackward>)
# - 옆방에서의 소리가 잘 들리고, 화장실의 청결 상태가 별로였음.
# tensor([0.9372, 0.0571], device='cuda:0', grad_fn=<SigmoidBackward>)
# 정확히 새벽6시에 클럽음악이 꺼졌다가 아침 9시 무렵에 다시 음악이 켜집니다.
# tensor([0.9334, 0.0588], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주차장이 없어시 별도의 주차비가 든다.
# tensor([0.9693, 0.0246], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구에 머리카락이 있네요
# tensor([0.9545, 0.0376], device='cuda:0', grad_fn=<SigmoidBackward>)
# 13층 룸의 온도가 29도 였어요
# tensor([0.9614, 0.0336], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이 호텔에서 3번 묵었는데, 2번째 묵었을때 방에 욕조에 물이 잘 안빠져나가더라구요.
# tensor([0.9372, 0.0556], device='cuda:0', grad_fn=<SigmoidBackward>)
# 숙소 내 0번을 통하여 추가 웰컴티 요청, 다림질 서비스 요청, 추가 어메니티 및 물 등 기타 물품 수령을 편하게 할 수 있었고 숙소가 높은 만큼 엘리베이터 대기를 많이 걱정했는데 한번도 1분 이상 기다린 적이 없네요~
# tensor([0.0342, 0.9661], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식은 생각보다 더 안좋았습니다.
# tensor([0.9583, 0.0353], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조식 포함이라고 했는데 조식은 없고 6층에 간단한 스낵바있어요.
# tensor([0.8993, 0.0950], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아이들과 가까운 곳에서 잘 즐겼습니다.
# tensor([0.1843, 0.8145], device='cuda:0', grad_fn=<SigmoidBackward>)
# 발렛파킹 서비스가 별로인데 5000원을 내야함 욕조 발매트가 없어서 살짝불편함
# tensor([0.9363, 0.0556], device='cuda:0', grad_fn=<SigmoidBackward>)
# 또 바닥에 앉았다가 일어나니 피부에 먼지와 알 수 없는 것들이 묻어 있었음. 고로 청소를 정말 대충하고 제대로 안한다는 것을 알 수 있었음. 4. 창문으로 도시뷰가 보인다는데 앞에 커다란 건물들이 있어서 시야를 다 가리고 있음. 도시뷰는 애초에 기대를 하면 안 됨. 5. 요즘 시골 모텔 같은 곳에 가도 가운이 있고 칫솔, 치약 외에도 면봉이나 화장솜 같은 부가적인 것들을 챙겨주는 데 여기는 그런 것이 하나도 없었음. 칫솔과 치약만 받을 수 있음. 6. 전화기가 있으나 프론트 번호와 위급상황 발생시 연락할 만한 전화번호가 하나도 쓰여있지 않았음. 7. 콘센트가 있으나 되는 것이 있고 안 되는 것이 있어 복불복임.
# tensor([0.9534, 0.0401], device='cuda:0', grad_fn=<SigmoidBackward>)
# 오후 3시 체크인에 한 시간 늦은 4시에 도착했음에도 청소가 되어 있지 않아 다른 방으로 임시 배정 받았습니다.
# tensor([0.9591, 0.0361], device='cuda:0', grad_fn=<SigmoidBackward>)
# 덜덜떨면서 밥먹었습니다
# tensor([0.9246, 0.0685], device='cuda:0', grad_fn=<SigmoidBackward>)
# 자주가던곳이라,늘 기대만큼잘이용하고옵니다.
# tensor([0.0269, 0.9722], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다음에도 또 오고 싶네요 ㅎ
# tensor([0.1310, 0.8688], device='cuda:0', grad_fn=<SigmoidBackward>)
# 서비스는 진짜 최상이었어요.
# tensor([0.0943, 0.9024], device='cuda:0', grad_fn=<SigmoidBackward>)
# 종종 이용하는 곳인데요
# tensor([0.3652, 0.6336], device='cuda:0', grad_fn=<SigmoidBackward>)
# 시설은 아주 새것이었는데, 왜인지 모르게 수건이 조금 낡았고 얼룩도 조금 있었다.
# tensor([0.8929, 0.0996], device='cuda:0', grad_fn=<SigmoidBackward>)
# 좀더 친절한 표시가 있어야 할 필요가 있어보였습니다.
# tensor([0.9606, 0.0331], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수압이 조금 약해요
# tensor([0.9590, 0.0349], device='cuda:0', grad_fn=<SigmoidBackward>)
# 주차장 관리 요원 (입출차)이 등롣된 차량임에도 불구하고, 입주 3일까지 매번 물어봄. 자동 입출차 시스템이나, 카드로 변경이 필요함. 주차장 티켓이 작은 종이한장 (쪽지 정도 사이즈) 임에도 불구하고 매번 찾느라 고생함.
# tensor([0.9641, 0.0300], device='cuda:0', grad_fn=<SigmoidBackward>)
# 모든게 다 좋았네요
# tensor([0.1628, 0.8359], device='cuda:0', grad_fn=<SigmoidBackward>)
# 조금 추웠습니다
# tensor([0.9140, 0.0770], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그앞이라 더좋네요
# tensor([0.0560, 0.9458], device='cuda:0', grad_fn=<SigmoidBackward>)
# 살면서 본 중 가장 작은 욕실이었던 듯. 변기에 들어가 앉으려면 세면대를 피해 비스듬히 들어가야 했고(심지어 체구가 작은 편인데도 불편!) 세면대에서 손이라도 씻은 후엔 변기에 앉아있을 때 무릎으로 물이 뚝뚝 떨어짐..ㅠ 이런 거야 설계 자체가 그리 돼 있으니 개선의 여지가 없다 해도, 후기에 여러차례 지적된 객실 청소 문제도 역시나였고 (린넨 청결도가 전반적으로 떨어짐.) 욕실 벽에도 물때 흔적이 그대로 있어 청소를 꼼꼼히 하지 않았다는 것이 너무 여실히 느껴짐.. 집 공사하는 동안 장기투숙할 목적이라 저렴한 숙소를 골랐던 것이고, 와서 잠만 자고 갈 출장이라거나 하는 목적이라면 그럭저럭 지낼 만은 하겠지만 호캉스 목적이라면 고르기 어려울 숙소. (결국 일주일 지내고 다른 호텔로 옮겼습니다 ㅠㅠ)
# tensor([0.9430, 0.0507], device='cuda:0', grad_fn=<SigmoidBackward>)
# 숙소를 잘못 예약한 결과로 저희 즐거운 여정이 망할뻔 했습니다..
# tensor([0.8959, 0.0970], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대는 푹신했으나 환기 때문인지 잠이 푹오지 않앗다
# tensor([0.9584, 0.0372], device='cuda:0', grad_fn=<SigmoidBackward>)
# 위치적인 것은 말할 것도 없는 위치지요.
# tensor([0.0251, 0.9744], device='cuda:0', grad_fn=<SigmoidBackward>)
# 수영장 등 편의시설도 좋고 사람이 그리 많지 않은 점도 장점.
# tensor([0.0256, 0.9743], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침대가 작아서 불편. 침대헤드부분..먼지가 소복..ㅠ 후~ 불으니 먼지가 막 날리는 정도였어요.
# tensor([0.9661, 0.0290], device='cuda:0', grad_fn=<SigmoidBackward>)
# 필름 무늬 목으로 만들어진 ;; 내부가 정말 이게 대한민국 최고 호텔이 맞나 싶은 정도였어요.
# tensor([0.9445, 0.0490], device='cuda:0', grad_fn=<SigmoidBackward>)
# 신선하고 골고른 음식에 정성이 더해 좋았습니다.
# tensor([0.0886, 0.9096], device='cuda:0', grad_fn=<SigmoidBackward>)
# 침구 편안해요.
# tensor([0.0592, 0.9399], device='cuda:0', grad_fn=<SigmoidBackward>)
# 깔끔해서 좋아요
# tensor([0.1894, 0.8091], device='cuda:0', grad_fn=<SigmoidBackward>)
# 아늑 하면서 쾌적한 룸이 좋았고 조식 맛집 입니다.
# tensor([0.0472, 0.9531], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1석 ???조
# tensor([0.8865, 0.1110], device='cuda:0', grad_fn=<SigmoidBackward>)
# 기회가 있다면 다시 투숙할 의사 있습니다.
# tensor([0.0420, 0.9575], device='cuda:0', grad_fn=<SigmoidBackward>)
# 1)조식 실망 조식이 너무 먹을게 없어서 실망했어요. 여태까지 먹었던 모든 호텔 조식 중에 가장 별로였다는.. 맛도 없고 먹을 것도 없고 최악.. 저렴하다해도 이건 좀.. ㅜ ㅠ 조식 먹으려고 일찍 일어난 시간이 아까웠어요. 2) 숙박키 숙박키도 한 개씩만 줘서 매우 불편했어요.
# tensor([0.9486, 0.0457], device='cuda:0', grad_fn=<SigmoidBackward>)
# 호캉스 즐기기에 나쁘지 않았음 청결하고 깔끔 뷰도 좋고 고급진 느낌
# tensor([0.0331, 0.9668], device='cuda:0', grad_fn=<SigmoidBackward>)
# 방이 쾌적하고 피트니스 시설도 좋았습니다.
# tensor([0.0368, 0.9639], device='cuda:0', grad_fn=<SigmoidBackward>)
# 11층까지 올라 갔다가 다시 내려왔네요,,,^^ㅠ
# tensor([0.9680, 0.0264], device='cuda:0', grad_fn=<SigmoidBackward>)
# 근처에 먹거리 골목도 있어 맛있는것도 많이 먹을수 있었고 지하철역도 가까워서 다니기 너무 좋았습니다.
# tensor([0.0344, 0.9660], device='cuda:0', grad_fn=<SigmoidBackward>)
# 후문쪽 엘레베이터에서 외부로 나가서 로비로 들어가야 하는 동선이 되는데, 설명오 조금 부족하고, 요즘처럼 비가 많이 올때 노출되어 있는 외부로 나가는것이 매우 안 좋았습니다.
# tensor([0.9546, 0.0399], device='cuda:0', grad_fn=<SigmoidBackward>)
# 크게 춥지는 않아서 컴플레인은 걸지 않앗으니 만족스럽지는 않앗습니다
# tensor([0.3282, 0.6527], device='cuda:0', grad_fn=<SigmoidBackward>)
# 전체적으로 깨끗했어요
# tensor([0.1219, 0.8752], device='cuda:0', grad_fn=<SigmoidBackward>)
# 제가 있는 층에 와이파이가 안되서 문의했더니 고장났다고 밑에 층을 사용하라고 하시더라구요.
# tensor([0.8814, 0.1113], device='cuda:0', grad_fn=<SigmoidBackward>)
# 이불을 빨은 건 알겠지만 이불에 다른게 묻어서 지워지지 않는 건지 조금 부족한 느낌이었습니다
# tensor([0.9509, 0.0456], device='cuda:0', grad_fn=<SigmoidBackward>)
# 에어컨이 객실 전체를 시원하게 하기엔 너무 약했다
# tensor([0.9068, 0.0849], device='cuda:0', grad_fn=<SigmoidBackward>)
# 다른곳에 비해 1~2만원 정도 비싸긴 했지만 간단히 컵라면 정도 끓일 수 있게 식기구가 조금 있어서 넘 좋았어요 ^^
# tensor([0.0344, 0.9665], device='cuda:0', grad_fn=<SigmoidBackward>)
# 그리고 방음이 아주 잘되는거 같더라구요.
# tensor([0.0235, 0.9777], device='cuda:0', grad_fn=<SigmoidBackward>)
# 안락하고 편히 쉬었고 청소도 깨끗했습니다
# tensor([0.0668, 0.9338], device='cuda:0', grad_fn=<SigmoidBackward>)
#
# Accuracy: tensor(0.9331, device='cuda:0')

# %%
# 모델 저장하기
torch.save(model.state_dict(), "model.pt")
